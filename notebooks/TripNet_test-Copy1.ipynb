# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from modelval import pairptl, network, trainer, dataset
from modelval.ArbDataGen import arb_w_gen

% matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# Visualize kernel
from modelval.kernel import KernelGen
plt.figure(figsize=(5,3))
ker_test = KernelGen()
ker_test.kernel_pre = KernelGen().uni_exp_ker(side='left', tau=20, scale=0.1)
ker_test.kernel_post = KernelGen().uni_exp_ker(side='left', tau=20, scale=0.1)
ker_test.kernel_post_post = KernelGen().uni_exp_ker(side='left', tau=50, scale=0.1)
plt.plot(ker_test.kernel_pre, label='ker_pre')
plt.plot(ker_test.kernel_post, label='ker_post')
plt.plot(ker_test.kernel_post_post, label='ker_post_post')
plt.legend()
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# Load data frame
data = pd.read_csv('/src/Plasticity_Ker/data/kernel_training_data_auto.csv')
data['train_len'] = data['ptl_occ'] / data['ptl_freq']
data.head()
# Out:
#    ptl_idx  pre_spk_num  pre_spk_freq  post_spk_num  post_spk_freq  ptl_occ  \
# 0        1            1             0             1              0       60
# 1        1            1             0             1              0       60
# 2        1            1             0             1              0       60
# 3        1            1             0             1              0       60
# 4        1            1             0             1              0       60
#
#    ptl_freq         dt1  dt2  dt3    dw_mean  dw_ste  train_len
# 0       1.0 -102.898046  0.0    0  -1.322590     0.0       60.0
# 1       1.0  -75.579896  0.0    0   2.674768     0.0       60.0
# 2       1.0  -80.871473  0.0    0 -12.696449     0.0       60.0
# 3       1.0  -67.562239  0.0    0   0.231446     0.0       60.0
# 4       1.0  -63.553410  0.0    0  -0.990216     0.0       60.0

# %%
# Generate data
ptl_list = [2,3,4]
spk_len = int(data[data['ptl_idx'].isin(ptl_list)]['train_len'].max() * 1000 / ker_test.reso_kernel)
spk_pairs, targets = arb_w_gen(df=data, ptl_list=ptl_list, spk_len=spk_len, kernel=ker_test, aug_times=10, net_type='triplet')
# targets = np.expand_dims(np.expand_dims(targets, axis=1), axis=2)

# %%
# Create the network
ground_truth_init = 0
toy_data_net2 = network.TripNet(kernel=ker_test, ground_truth_init=ground_truth_init, n_input=spk_pairs.shape[1])

# %%
# Create the trainer
save_dir= '/src/Plasticity_Ker/model/TripNet_ptl2-4_toy'
toy_net2_trainer = trainer.Trainer(toy_data_net2.loss, input_name=toy_data_net2.inputs, target_name=toy_data_net2.target, save_dir=save_dir, optimizer_config={'learning_rate': toy_data_net2.lr})

# %%
# Obtain the training and validation data
from sklearn.model_selection import train_test_split

X_train, X_vali, y_train, y_vali = train_test_split(spk_pairs, targets, test_size=0.1)
train_data = dataset.Dataset(X_train, y_train)
vali_data = dataset.Dataset(X_vali, y_vali)

# %%
w_pre = toy_net2_trainer.evaluate(ops=toy_data_net2.kernel_pre)
w_post = toy_net2_trainer.evaluate(ops=toy_data_net2.kernel_post)
w_post_post = toy_net2_trainer.evaluate(ops=toy_data_net2.kernel_post_post)
plt.plot(w_pre, label='ker_pre_init')
plt.plot(w_post, label='ker_post_init')
plt.plot(w_post_post, label='ker_post_post_init')
bias = toy_net2_trainer.evaluate(ops=toy_data_net2.bias)
plt.legend()
bias
# Out:
# 0.0
# /usr/local/lib/python3.5/dist-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# Learn the kernel from random initialization
learning_rate = 0.001
iterations = 5
min_error = -1
for i in range(iterations):
    toy_net2_trainer.train(train_data, vali_data, batch_size=128, min_error=min_error, feed_dict={toy_data_net2.lr: learning_rate})
    learning_rate = learning_rate/3
# Out:
# Initial validation cost=92.34470
# Global Step 0150 and Step 0150: validation cost=18.13450
# Updated min validation loss!Saving model...
# Global Step 0200 and Step 0200: validation cost=12.75206
# Updated min validation loss!Saving model...
# Global Step 0250 and Step 0250: validation cost=9.31864
# Updated min validation loss!Saving model...
# Global Step 0300 and Step 0300: validation cost=6.96068
# Updated min validation loss!Saving model...
# Global Step 0350 and Step 0350: validation cost=5.20732
# Updated min validation loss!Saving model...
# Global Step 0400 and Step 0400: validation cost=4.00159
# Updated min validation loss!Saving model...
# Global Step 0450 and Step 0450: validation cost=3.12327
# Updated min validation loss!Saving model...
# Global Step 0500 and Step 0500: validation cost=2.49781
# Updated min validation loss!Saving model...
# Global Step 0550 and Step 0550: validation cost=2.02834
# Updated min validation loss!Saving model...
# Global Step 0600 and Step 0600: validation cost=1.68273
# Updated min validation loss!Saving model...
# Global Step 0650 and Step 0650: validation cost=1.40645
# Updated min validation loss!Saving model...
# Global Step 0700 and Step 0700: validation cost=1.19760
# Updated min validation loss!Saving model...
# Global Step 0750 and Step 0750: validation cost=1.03164
# Updated min validation loss!Saving model...
# Global Step 0800 and Step 0800: validation cost=0.89407
# Updated min validation loss!Saving model...
# Global Step 0850 and Step 0850: validation cost=0.78425
# Updated min validation loss!Saving model...
# Global Step 0900 and Step 0900: validation cost=0.69067
# Updated min validation loss!Saving model...
# Global Step 0950 and Step 0950: validation cost=0.61364
# Updated min validation loss!Saving model...
# Global Step 1000 and Step 1000: validation cost=0.54805
# Updated min validation loss!Saving model...
# Global Step 1050 and Step 1050: validation cost=0.49065
# Updated min validation loss!Saving model...
# Global Step 1100 and Step 1100: validation cost=0.44304
# Updated min validation loss!Saving model...
# Global Step 1150 and Step 1150: validation cost=0.39991
# Updated min validation loss!Saving model...
# Global Step 1200 and Step 1200: validation cost=0.36780
# Updated min validation loss!Saving model...
# Global Step 1250 and Step 1250: validation cost=0.33759
# Updated min validation loss!Saving model...
# Global Step 1300 and Step 1300: validation cost=0.31007
# Updated min validation loss!Saving model...
# Global Step 1350 and Step 1350: validation cost=0.28349
# Updated min validation loss!Saving model...
# Global Step 1400 and Step 1400: validation cost=0.26576
# Updated min validation loss!Saving model...
# Global Step 1450 and Step 1450: validation cost=0.24613
# Updated min validation loss!Saving model...
# Global Step 1500 and Step 1500: validation cost=0.23086
# Updated min validation loss!Saving model...
# Global Step 1550 and Step 1550: validation cost=0.21661
# Updated min validation loss!Saving model...
# Global Step 1600 and Step 1600: validation cost=0.20045
# Updated min validation loss!Saving model...
# Global Step 1650 and Step 1650: validation cost=0.18888
# Updated min validation loss!Saving model...
# Global Step 1700 and Step 1700: validation cost=0.17735
# Updated min validation loss!Saving model...
# Global Step 1750 and Step 1750: validation cost=0.16702
# Updated min validation loss!Saving model...
# Global Step 1800 and Step 1800: validation cost=0.15733
# Updated min validation loss!Saving model...
# Global Step 1850 and Step 1850: validation cost=0.15036
# Updated min validation loss!Saving model...
# Global Step 1900 and Step 1900: validation cost=0.14283
# Updated min validation loss!Saving model...
# Global Step 1950 and Step 1950: validation cost=0.13733
# Updated min validation loss!Saving model...
# Global Step 2000 and Step 2000: validation cost=0.12920
# Updated min validation loss!Saving model...
# Global Step 2050 and Step 2050: validation cost=0.12331
# Updated min validation loss!Saving model...
# Global Step 2100 and Step 2100: validation cost=0.11971
# Updated min validation loss!Saving model...
# Global Step 2150 and Step 2150: validation cost=0.11485
# Updated min validation loss!Saving model...
# Global Step 2200 and Step 2200: validation cost=0.10825
# Updated min validation loss!Saving model...
# Global Step 2250 and Step 2250: validation cost=0.10486
# Updated min validation loss!Saving model...
# Global Step 2300 and Step 2300: validation cost=0.09947
# Updated min validation loss!Saving model...
# Global Step 2350 and Step 2350: validation cost=0.09652
# Updated min validation loss!Saving model...
# Global Step 2400 and Step 2400: validation cost=0.09280
# Updated min validation loss!Saving model...
# Global Step 2450 and Step 2450: validation cost=0.09009
# Updated min validation loss!Saving model...
# Global Step 2500 and Step 2500: validation cost=0.08478
# Updated min validation loss!Saving model...
# Global Step 2550 and Step 2550: validation cost=0.08292
# Updated min validation loss!Saving model...
# Global Step 2600 and Step 2600: validation cost=0.08030
# Updated min validation loss!Saving model...
# Global Step 2650 and Step 2650: validation cost=0.07674
# Updated min validation loss!Saving model...
# Global Step 2700 and Step 2700: validation cost=0.07432
# Updated min validation loss!Saving model...
# Global Step 2750 and Step 2750: validation cost=0.07193
# Updated min validation loss!Saving model...
# Global Step 2800 and Step 2800: validation cost=0.06949
# Updated min validation loss!Saving model...
# Global Step 2850 and Step 2850: validation cost=0.06831
# Updated min validation loss!Saving model...
# Global Step 2900 and Step 2900: validation cost=0.06578
# Updated min validation loss!Saving model...
# Global Step 2950 and Step 2950: validation cost=0.06325
# Updated min validation loss!Saving model...
# Global Step 3000 and Step 3000: validation cost=0.06025
# Updated min validation loss!Saving model...
# Global Step 3050 and Step 3050: validation cost=0.06119
# Global Step 3100 and Step 3100: validation cost=0.05625
# Updated min validation loss!Saving model...
# Global Step 3150 and Step 3150: validation cost=0.05618
# Updated min validation loss!Saving model...
# Global Step 3200 and Step 3200: validation cost=0.05580
# Updated min validation loss!Saving model...
# Global Step 3250 and Step 3250: validation cost=0.05254
# Updated min validation loss!Saving model...
# Global Step 3300 and Step 3300: validation cost=0.05375
# Global Step 3350 and Step 3350: validation cost=0.05103
# Updated min validation loss!Saving model...
# Global Step 3400 and Step 3400: validation cost=0.04929
# Updated min validation loss!Saving model...
# Global Step 3450 and Step 3450: validation cost=0.04773
# Updated min validation loss!Saving model...
# Global Step 3500 and Step 3500: validation cost=0.04619
# Updated min validation loss!Saving model...
# Global Step 3550 and Step 3550: validation cost=0.04559
# Updated min validation loss!Saving model...
# Global Step 3600 and Step 3600: validation cost=0.04412
# Updated min validation loss!Saving model...
# Global Step 3650 and Step 3650: validation cost=0.04346
# Updated min validation loss!Saving model...
# Global Step 3700 and Step 3700: validation cost=0.04211
# Updated min validation loss!Saving model...
# Global Step 3750 and Step 3750: validation cost=0.04064
# Updated min validation loss!Saving model...
# Global Step 3800 and Step 3800: validation cost=0.03990
# Updated min validation loss!Saving model...
# Global Step 3850 and Step 3850: validation cost=0.03883
# Updated min validation loss!Saving model...
# Global Step 3900 and Step 3900: validation cost=0.03919
# Global Step 3950 and Step 3950: validation cost=0.03920
# Global Step 4000 and Step 4000: validation cost=0.03743
# Updated min validation loss!Saving model...
# Global Step 4050 and Step 4050: validation cost=0.03750
# Global Step 4100 and Step 4100: validation cost=0.03602
# Updated min validation loss!Saving model...
# Global Step 4150 and Step 4150: validation cost=0.03593
# Updated min validation loss!Saving model...
# Global Step 4200 and Step 4200: validation cost=0.03481
# Updated min validation loss!Saving model...
# Global Step 4250 and Step 4250: validation cost=0.03457
# Updated min validation loss!Saving model...
# Global Step 4300 and Step 4300: validation cost=0.03435
# Updated min validation loss!Saving model...
# Global Step 4350 and Step 4350: validation cost=0.03351
# Updated min validation loss!Saving model...
# Global Step 4400 and Step 4400: validation cost=0.03325
# Updated min validation loss!Saving model...
# Global Step 4450 and Step 4450: validation cost=0.03158
# Updated min validation loss!Saving model...
# Global Step 4500 and Step 4500: validation cost=0.03302
# Global Step 4550 and Step 4550: validation cost=0.03101
# Updated min validation loss!Saving model...
# Global Step 4600 and Step 4600: validation cost=0.03181
# Global Step 4650 and Step 4650: validation cost=0.02975
# Updated min validation loss!Saving model...
# Global Step 4700 and Step 4700: validation cost=0.02899
# Updated min validation loss!Saving model...
# Global Step 4750 and Step 4750: validation cost=0.02939
# Global Step 4800 and Step 4800: validation cost=0.02963
# Global Step 4850 and Step 4850: validation cost=0.02730
# Updated min validation loss!Saving model...
# Global Step 4900 and Step 4900: validation cost=0.02682
# Updated min validation loss!Saving model...
# Global Step 4950 and Step 4950: validation cost=0.02670
# Updated min validation loss!Saving model...
# Global Step 5000 and Step 5000: validation cost=0.02788
# Global Step 5050 and Step 5050: validation cost=0.02637
# Updated min validation loss!Saving model...
# Global Step 5100 and Step 5100: validation cost=0.02698
# Global Step 5150 and Step 5150: validation cost=0.02533
# Updated min validation loss!Saving model...
# Global Step 5200 and Step 5200: validation cost=0.02546
# Global Step 5250 and Step 5250: validation cost=0.02379
# Updated min validation loss!Saving model...
# Global Step 5300 and Step 5300: validation cost=0.02381
# Global Step 5350 and Step 5350: validation cost=0.02331
# Updated min validation loss!Saving model...
# Global Step 5400 and Step 5400: validation cost=0.02214
# Updated min validation loss!Saving model...
# Global Step 5450 and Step 5450: validation cost=0.02181
# Updated min validation loss!Saving model...
# Global Step 5500 and Step 5500: validation cost=0.02195
# Global Step 5550 and Step 5550: validation cost=0.02026
# Updated min validation loss!Saving model...
# Global Step 5600 and Step 5600: validation cost=0.02034
# Global Step 5650 and Step 5650: validation cost=0.02040
# Global Step 5700 and Step 5700: validation cost=0.01973
# Updated min validation loss!Saving model...
# Global Step 5750 and Step 5750: validation cost=0.01900
# Updated min validation loss!Saving model...
# Global Step 5800 and Step 5800: validation cost=0.01833
# Updated min validation loss!Saving model...
# Global Step 5850 and Step 5850: validation cost=0.01751
# Updated min validation loss!Saving model...
# Global Step 5900 and Step 5900: validation cost=0.01674
# Updated min validation loss!Saving model...
# Global Step 5950 and Step 5950: validation cost=0.01637
# Updated min validation loss!Saving model...
# Global Step 6000 and Step 6000: validation cost=0.01700
# Global Step 6050 and Step 6050: validation cost=0.01551
# Updated min validation loss!Saving model...
# Global Step 6100 and Step 6100: validation cost=0.01438
# Updated min validation loss!Saving model...
# Global Step 6150 and Step 6150: validation cost=0.01434
# Updated min validation loss!Saving model...
# Global Step 6200 and Step 6200: validation cost=0.01389
# Updated min validation loss!Saving model...
# Global Step 6250 and Step 6250: validation cost=0.01187
# Updated min validation loss!Saving model...
# Global Step 6300 and Step 6300: validation cost=0.01249
# Global Step 6350 and Step 6350: validation cost=0.01261
# Global Step 6400 and Step 6400: validation cost=0.01117
# Updated min validation loss!Saving model...
# Global Step 6450 and Step 6450: validation cost=0.01068
# Updated min validation loss!Saving model...
# Global Step 6500 and Step 6500: validation cost=0.01005
# Updated min validation loss!Saving model...
# Global Step 6550 and Step 6550: validation cost=0.01038
# Global Step 6600 and Step 6600: validation cost=0.00887
# Updated min validation loss!Saving model...
# Global Step 6650 and Step 6650: validation cost=0.00934
# Global Step 6700 and Step 6700: validation cost=0.00864
# Updated min validation loss!Saving model...
# Global Step 6750 and Step 6750: validation cost=0.00909
# Global Step 6800 and Step 6800: validation cost=0.00833
# Updated min validation loss!Saving model...
# Global Step 6850 and Step 6850: validation cost=0.00816
# Updated min validation loss!Saving model...
# Global Step 6900 and Step 6900: validation cost=0.00804
# Updated min validation loss!Saving model...
# Global Step 6950 and Step 6950: validation cost=0.00702
# Updated min validation loss!Saving model...
# Global Step 7000 and Step 7000: validation cost=0.00724
# Global Step 7050 and Step 7050: validation cost=0.00662
# Updated min validation loss!Saving model...
# Global Step 7100 and Step 7100: validation cost=0.00726
# Global Step 7150 and Step 7150: validation cost=0.00611
# Updated min validation loss!Saving model...
# Global Step 7200 and Step 7200: validation cost=0.00571
# Updated min validation loss!Saving model...
# Global Step 7250 and Step 7250: validation cost=0.00567
# Updated min validation loss!Saving model...
# Global Step 7300 and Step 7300: validation cost=0.00565
# Updated min validation loss!Saving model...
# Global Step 7350 and Step 7350: validation cost=0.00538
# Updated min validation loss!Saving model...
# Global Step 7400 and Step 7400: validation cost=0.00533
# Updated min validation loss!Saving model...
# Global Step 7450 and Step 7450: validation cost=0.00521
# Updated min validation loss!Saving model...
# Global Step 7500 and Step 7500: validation cost=0.00540
# Global Step 7550 and Step 7550: validation cost=0.00448
# Updated min validation loss!Saving model...
# Global Step 7600 and Step 7600: validation cost=0.00438
# Updated min validation loss!Saving model...
# Global Step 7650 and Step 7650: validation cost=0.00507
# Global Step 7700 and Step 7700: validation cost=0.00463
# Global Step 7750 and Step 7750: validation cost=0.00499
# Global Step 7800 and Step 7800: validation cost=0.00468
# Global Step 7850 and Step 7850: validation cost=0.00500
# Global Step 7900 and Step 7900: validation cost=0.00433
# Updated min validation loss!Saving model...
# Global Step 7950 and Step 7950: validation cost=0.00415
# Updated min validation loss!Saving model...
# Global Step 8000 and Step 8000: validation cost=0.00387
# Updated min validation loss!Saving model...
# Global Step 8050 and Step 8050: validation cost=0.00384
# Updated min validation loss!Saving model...
# Global Step 8100 and Step 8100: validation cost=0.00426
# Global Step 8150 and Step 8150: validation cost=0.00339
# Updated min validation loss!Saving model...
# Global Step 8200 and Step 8200: validation cost=0.00361
# Global Step 8250 and Step 8250: validation cost=0.00383
# Global Step 8300 and Step 8300: validation cost=0.00378
# Global Step 8350 and Step 8350: validation cost=0.00312
# Updated min validation loss!Saving model...
# Global Step 8400 and Step 8400: validation cost=0.00367
# Global Step 8450 and Step 8450: validation cost=0.00362
# Global Step 8500 and Step 8500: validation cost=0.00306
# Updated min validation loss!Saving model...
# Global Step 8550 and Step 8550: validation cost=0.00322
# Global Step 8600 and Step 8600: validation cost=0.00364
# Global Step 8650 and Step 8650: validation cost=0.00335
# Global Step 8700 and Step 8700: validation cost=0.00364
# Global Step 8750 and Step 8750: validation cost=0.00345
# Global Step 8800 and Step 8800: validation cost=0.00369
# Global Step 8850 and Step 8850: validation cost=0.00335
# Global Step 8900 and Step 8900: validation cost=0.00353
# Global Step 8950 and Step 8950: validation cost=0.00403
# Global Step 9000 and Step 9000: validation cost=0.00313
# Global Step 9050 and Step 9050: validation cost=0.00274
# Updated min validation loss!Saving model...
# Global Step 9100 and Step 9100: validation cost=0.00335
# Global Step 9150 and Step 9150: validation cost=0.00246
# Updated min validation loss!Saving model...
# Global Step 9200 and Step 9200: validation cost=0.00319
# Global Step 9250 and Step 9250: validation cost=0.00274
# Global Step 9300 and Step 9300: validation cost=0.00304
# Global Step 9350 and Step 9350: validation cost=0.00294
# Global Step 9400 and Step 9400: validation cost=0.00280
# Global Step 9450 and Step 9450: validation cost=0.00318
# Global Step 9500 and Step 9500: validation cost=0.00268
# Global Step 9550 and Step 9550: validation cost=0.00216
# Updated min validation loss!Saving model...
# Global Step 9600 and Step 9600: validation cost=0.00270
# Global Step 9650 and Step 9650: validation cost=0.00266
# Global Step 9700 and Step 9700: validation cost=0.00246
# Global Step 9750 and Step 9750: validation cost=0.00292
# Global Step 9800 and Step 9800: validation cost=0.00276
# Global Step 9850 and Step 9850: validation cost=0.00256
# Global Step 9900 and Step 9900: validation cost=0.00250
# Global Step 9950 and Step 9950: validation cost=0.00281
# Global Step 10000 and Step 10000: validation cost=0.00304
# Global Step 10050 and Step 10050: validation cost=0.00256
# Global Step 10100 and Step 10100: validation cost=0.00236
# Global Step 10150 and Step 10150: validation cost=0.00231
# Global Step 10200 and Step 10200: validation cost=0.00304
# Global Step 10250 and Step 10250: validation cost=0.00282
# Global Step 10300 and Step 10300: validation cost=0.00291
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 10350 and Step 0050: validation cost=0.00251
# Global Step 10400 and Step 0100: validation cost=0.00246
# Global Step 10450 and Step 0150: validation cost=0.00269
# Global Step 10500 and Step 0200: validation cost=0.00260
# Global Step 10550 and Step 0250: validation cost=0.00253
# Global Step 10600 and Step 0300: validation cost=0.00248
# Global Step 10650 and Step 0350: validation cost=0.00278
# Global Step 10700 and Step 0400: validation cost=0.00261
# Global Step 10750 and Step 0450: validation cost=0.00266
# Global Step 10800 and Step 0500: validation cost=0.00251
# Global Step 10850 and Step 0550: validation cost=0.00251
# Global Step 10900 and Step 0600: validation cost=0.00261
# Global Step 10950 and Step 0650: validation cost=0.00255
# Global Step 11000 and Step 0700: validation cost=0.00270
# Global Step 11050 and Step 0750: validation cost=0.00249
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 11100 and Step 0050: validation cost=0.00248
# Global Step 11150 and Step 0100: validation cost=0.00250
# Global Step 11200 and Step 0150: validation cost=0.00247
# Global Step 11250 and Step 0200: validation cost=0.00248
# Global Step 11300 and Step 0250: validation cost=0.00253
# Global Step 11350 and Step 0300: validation cost=0.00252
# Global Step 11400 and Step 0350: validation cost=0.00253
# Global Step 11450 and Step 0400: validation cost=0.00252
# Global Step 11500 and Step 0450: validation cost=0.00245
# Global Step 11550 and Step 0500: validation cost=0.00248
# Global Step 11600 and Step 0550: validation cost=0.00252
# Global Step 11650 and Step 0600: validation cost=0.00253
# Global Step 11700 and Step 0650: validation cost=0.00255
# Global Step 11750 and Step 0700: validation cost=0.00248
# Global Step 11800 and Step 0750: validation cost=0.00242
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 11850 and Step 0050: validation cost=0.00234
# Global Step 11900 and Step 0100: validation cost=0.00240
# Global Step 11950 and Step 0150: validation cost=0.00243
# Global Step 12000 and Step 0200: validation cost=0.00246
# Global Step 12050 and Step 0250: validation cost=0.00250
# Global Step 12100 and Step 0300: validation cost=0.00248
# Global Step 12150 and Step 0350: validation cost=0.00247
# Global Step 12200 and Step 0400: validation cost=0.00247
# Global Step 12250 and Step 0450: validation cost=0.00249
# Global Step 12300 and Step 0500: validation cost=0.00249
# Global Step 12350 and Step 0550: validation cost=0.00249
# Global Step 12400 and Step 0600: validation cost=0.00249
# Global Step 12450 and Step 0650: validation cost=0.00248
# Global Step 12500 and Step 0700: validation cost=0.00249
# Global Step 12550 and Step 0750: validation cost=0.00249
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 12600 and Step 0050: validation cost=0.00220
# Global Step 12650 and Step 0100: validation cost=0.00228
# Global Step 12700 and Step 0150: validation cost=0.00233
# Global Step 12750 and Step 0200: validation cost=0.00236
# Global Step 12800 and Step 0250: validation cost=0.00236
# Global Step 12850 and Step 0300: validation cost=0.00238
# Global Step 12900 and Step 0350: validation cost=0.00241
# Global Step 12950 and Step 0400: validation cost=0.00242
# Global Step 13000 and Step 0450: validation cost=0.00243
# Global Step 13050 and Step 0500: validation cost=0.00244
# Global Step 13100 and Step 0550: validation cost=0.00245
# Global Step 13150 and Step 0600: validation cost=0.00246
# Global Step 13200 and Step 0650: validation cost=0.00246
# Global Step 13250 and Step 0700: validation cost=0.00246
# Global Step 13300 and Step 0750: validation cost=0.00246
# Early Stopping!!!
# Restoring the best parameters...

# %%
w_pre = toy_net2_trainer.evaluate(ops=toy_data_net2.kernel_pre)
w_post = toy_net2_trainer.evaluate(ops=toy_data_net2.kernel_post)
w_post_post = toy_net2_trainer.evaluate(ops=toy_data_net2.kernel_post_post)
plt.plot(w_pre, label='ker_pre_init')
plt.plot(w_post, label='ker_post_init')
plt.plot(w_post_post, label='ker_post_post_init')
bias = toy_net2_trainer.evaluate(ops=toy_data_net2.bias)
plt.legend()
bias
# Out:
# 0.036609855
# /usr/local/lib/python3.5/dist-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
