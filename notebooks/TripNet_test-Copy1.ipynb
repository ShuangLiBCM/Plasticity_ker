# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from modelval import pairptl, network, trainer, dataset
from modelval.ArbDataGen import arb_w_gen

% matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Visualize kernel
from modelval.kernel import KernelGen
plt.figure(figsize=(5,3))
ker_test = KernelGen()
ker_test.kernel_pre = KernelGen().uni_exp_ker(side='left', tau=20, scale=0.1)
ker_test.kernel_post = KernelGen().uni_exp_ker(side='left', tau=20, scale=0.1)
ker_test.kernel_post_post = KernelGen().uni_exp_ker(side='left', tau=50, scale=0.1)
plt.plot(ker_test.kernel_pre, label='ker_pre')
plt.plot(ker_test.kernel_post, label='ker_post')
plt.plot(ker_test.kernel_post_post, label='ker_post_post')
plt.legend()
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# Load data frame
data = pd.read_csv('/src/Plasticity_Ker/data/kernel_training_data_auto.csv')
data['train_len'] = data['ptl_occ'] / data['ptl_freq']
data.head()
# Out:
#    ptl_idx  pre_spk_num  pre_spk_freq  post_spk_num  post_spk_freq  ptl_occ  \
# 0        1            1             0             1              0       60
# 1        1            1             0             1              0       60
# 2        1            1             0             1              0       60
# 3        1            1             0             1              0       60
# 4        1            1             0             1              0       60
#
#    ptl_freq         dt1  dt2  dt3    dw_mean  dw_ste  train_len
# 0       1.0 -102.898046  0.0    0  -1.322590     0.0       60.0
# 1       1.0  -75.579896  0.0    0   2.674768     0.0       60.0
# 2       1.0  -80.871473  0.0    0 -12.696449     0.0       60.0
# 3       1.0  -67.562239  0.0    0   0.231446     0.0       60.0
# 4       1.0  -63.553410  0.0    0  -0.990216     0.0       60.0

# %%
# Generate data
ptl_list = [2,3,4]
spk_len = int(data[data['ptl_idx'].isin(ptl_list)]['train_len'].max() * 1000 / ker_test.reso_kernel)
spk_pairs, targets = arb_w_gen(df=data, ptl_list=ptl_list, spk_len=spk_len, kernel=ker_test, aug_times=10, net_type='triplet')
# targets = np.expand_dims(np.expand_dims(targets, axis=1), axis=2)

# %%
# Create the network
ground_truth_init = 0
toy_data_net2 = network.TripNet(kernel=ker_test, ground_truth_init=ground_truth_init, n_input=spk_pairs.shape[1])

# %%
# Create the trainer
save_dir= '/src/Plasticity_Ker/model/TripNet_ptl2-4_toy'
toy_net2_trainer = trainer.Trainer(toy_data_net2.loss, input_name=toy_data_net2.inputs, target_name=toy_data_net2.target, save_dir=save_dir, optimizer_config={'learning_rate': toy_data_net2.lr})

# %%
# Obtain the training and validation data
from sklearn.model_selection import train_test_split

X_train, X_vali, y_train, y_vali = train_test_split(spk_pairs, targets, test_size=0.1)
train_data = dataset.Dataset(X_train, y_train)
vali_data = dataset.Dataset(X_vali, y_vali)

# %%
w_pre = toy_net2_trainer.evaluate(ops=toy_data_net2.kernel_pre)
w_post = toy_net2_trainer.evaluate(ops=toy_data_net2.kernel_post)
w_post_post = toy_net2_trainer.evaluate(ops=toy_data_net2.kernel_post_post)
plt.plot(w_pre, label='ker_pre_init')
plt.plot(w_post, label='ker_post_init')
plt.plot(w_post_post, label='ker_post_post_init')
bias = toy_net2_trainer.evaluate(ops=toy_data_net2.bias)
plt.legend()
bias
# Out:
# 0.0
# /usr/local/lib/python3.5/dist-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# Learn the kernel from random initialization
learning_rate = 0.001
iterations = 5
min_error = -1
for i in range(iterations):
    toy_net2_trainer.train(train_data, vali_data, batch_size=128, min_error=min_error, feed_dict={toy_data_net2.lr: learning_rate})
    learning_rate = learning_rate/3
# Out:
# Global Step 8200 and Step 0039: validation cost=0.00425
# Updated min validation loss!Saving model...
# Global Step 8250 and Step 0089: validation cost=0.00422
# Updated min validation loss!Saving model...
# Global Step 8300 and Step 0139: validation cost=0.00397
# Updated min validation loss!Saving model...
# Global Step 8350 and Step 0189: validation cost=0.00389
# Updated min validation loss!Saving model...
# Global Step 8400 and Step 0239: validation cost=0.00372
# Updated min validation loss!Saving model...
# Global Step 8450 and Step 0289: validation cost=0.00362
# Updated min validation loss!Saving model...
# Global Step 8500 and Step 0339: validation cost=0.00362
# Updated min validation loss!Saving model...
# Global Step 8550 and Step 0389: validation cost=0.00334
# Updated min validation loss!Saving model...
# Global Step 8600 and Step 0439: validation cost=0.00327
# Updated min validation loss!Saving model...
# Global Step 8650 and Step 0489: validation cost=0.00326
# Updated min validation loss!Saving model...
# Global Step 8700 and Step 0539: validation cost=0.00307
# Updated min validation loss!Saving model...
# Global Step 8750 and Step 0589: validation cost=0.00303
# Updated min validation loss!Saving model...
# Global Step 8800 and Step 0639: validation cost=0.00285
# Updated min validation loss!Saving model...
# Global Step 8850 and Step 0689: validation cost=0.00291
# Global Step 8900 and Step 0739: validation cost=0.00278
# Updated min validation loss!Saving model...
# Global Step 8950 and Step 0789: validation cost=0.00277
# Updated min validation loss!Saving model...
# Global Step 9000 and Step 0839: validation cost=0.00268
# Updated min validation loss!Saving model...
# Global Step 9050 and Step 0889: validation cost=0.00247
# Updated min validation loss!Saving model...
# Global Step 9100 and Step 0939: validation cost=0.00231
# Updated min validation loss!Saving model...
# Global Step 9150 and Step 0989: validation cost=0.00236
# Global Step 9200 and Step 1039: validation cost=0.00222
# Updated min validation loss!Saving model...
# Global Step 9250 and Step 1089: validation cost=0.00238
# Global Step 9300 and Step 1139: validation cost=0.00207
# Updated min validation loss!Saving model...
# Global Step 9350 and Step 1189: validation cost=0.00211
# Global Step 9400 and Step 1239: validation cost=0.00206
# Updated min validation loss!Saving model...
# Global Step 9450 and Step 1289: validation cost=0.00192
# Updated min validation loss!Saving model...
# Global Step 9500 and Step 1339: validation cost=0.00185
# Updated min validation loss!Saving model...
# Global Step 9550 and Step 1389: validation cost=0.00180
# Updated min validation loss!Saving model...
# Global Step 9600 and Step 1439: validation cost=0.00176
# Updated min validation loss!Saving model...
# Global Step 9650 and Step 1489: validation cost=0.00179
# Global Step 9700 and Step 1539: validation cost=0.00167
# Updated min validation loss!Saving model...
# Global Step 9750 and Step 1589: validation cost=0.00170
# Global Step 9800 and Step 1639: validation cost=0.00153
# Updated min validation loss!Saving model...
# Global Step 9850 and Step 1689: validation cost=0.00166
# Global Step 9900 and Step 1739: validation cost=0.00158
# Global Step 9950 and Step 1789: validation cost=0.00146
# Updated min validation loss!Saving model...
# Global Step 10000 and Step 1839: validation cost=0.00146
# Updated min validation loss!Saving model...
# Global Step 10050 and Step 1889: validation cost=0.00137
# Updated min validation loss!Saving model...
# Global Step 10100 and Step 1939: validation cost=0.00136
# Updated min validation loss!Saving model...
# Global Step 10150 and Step 1989: validation cost=0.00129
# Updated min validation loss!Saving model...
# Global Step 10200 and Step 2039: validation cost=0.00135
# Global Step 10250 and Step 2089: validation cost=0.00121
# Updated min validation loss!Saving model...
# Global Step 10300 and Step 2139: validation cost=0.00131
# Global Step 10350 and Step 2189: validation cost=0.00112
# Updated min validation loss!Saving model...
# Global Step 10400 and Step 2239: validation cost=0.00117
# Global Step 10450 and Step 2289: validation cost=0.00108
# Updated min validation loss!Saving model...
# Global Step 10500 and Step 2339: validation cost=0.00105
# Updated min validation loss!Saving model...
# Global Step 10550 and Step 2389: validation cost=0.00118
# Global Step 10600 and Step 2439: validation cost=0.00098
# Updated min validation loss!Saving model...
# Global Step 10650 and Step 2489: validation cost=0.00108
# Global Step 10700 and Step 2539: validation cost=0.00094
# Updated min validation loss!Saving model...
# Global Step 10750 and Step 2589: validation cost=0.00093
# Updated min validation loss!Saving model...
# Global Step 10800 and Step 2639: validation cost=0.00095
# Global Step 10850 and Step 2689: validation cost=0.00085
# Updated min validation loss!Saving model...
# Global Step 10900 and Step 2739: validation cost=0.00095
# Global Step 10950 and Step 2789: validation cost=0.00077
# Updated min validation loss!Saving model...
# Global Step 11000 and Step 2839: validation cost=0.00087
# Global Step 11050 and Step 2889: validation cost=0.00078
# Global Step 11100 and Step 2939: validation cost=0.00077
# Global Step 11150 and Step 2989: validation cost=0.00076
# Updated min validation loss!Saving model...
# Global Step 11200 and Step 3039: validation cost=0.00072
# Updated min validation loss!Saving model...
# Global Step 11250 and Step 3089: validation cost=0.00080
# Global Step 11300 and Step 3139: validation cost=0.00070
# Updated min validation loss!Saving model...
# Global Step 11350 and Step 3189: validation cost=0.00062
# Updated min validation loss!Saving model...
# Global Step 11400 and Step 3239: validation cost=0.00060
# Updated min validation loss!Saving model...
# Global Step 11450 and Step 3289: validation cost=0.00062
# Global Step 11500 and Step 3339: validation cost=0.00057
# Updated min validation loss!Saving model...
# Global Step 11550 and Step 3389: validation cost=0.00051
# Updated min validation loss!Saving model...
# Global Step 11600 and Step 3439: validation cost=0.00053
# Global Step 11650 and Step 3489: validation cost=0.00052
# Global Step 11700 and Step 3539: validation cost=0.00046
# Updated min validation loss!Saving model...
# Global Step 11750 and Step 3589: validation cost=0.00050
# Global Step 11800 and Step 3639: validation cost=0.00049
# Global Step 11850 and Step 3689: validation cost=0.00046
# Updated min validation loss!Saving model...
# Global Step 11900 and Step 3739: validation cost=0.00043
# Updated min validation loss!Saving model...
# Global Step 11950 and Step 3789: validation cost=0.00042
# Updated min validation loss!Saving model...
# Global Step 12000 and Step 3839: validation cost=0.00039
# Updated min validation loss!Saving model...
# Global Step 12050 and Step 3889: validation cost=0.00056
# Global Step 12100 and Step 3939: validation cost=0.00044
# Global Step 12150 and Step 3989: validation cost=0.00039
# Global Step 12200 and Step 4039: validation cost=0.00036
# Updated min validation loss!Saving model...
# Global Step 12250 and Step 4089: validation cost=0.00038
# Global Step 12300 and Step 4139: validation cost=0.00041
# Global Step 12350 and Step 4189: validation cost=0.00036
# Updated min validation loss!Saving model...
# Global Step 12400 and Step 4239: validation cost=0.00036
# Updated min validation loss!Saving model...
# Global Step 12450 and Step 4289: validation cost=0.00035
# Updated min validation loss!Saving model...
# Global Step 12500 and Step 4339: validation cost=0.00032
# Updated min validation loss!Saving model...
# Global Step 12550 and Step 4389: validation cost=0.00033
# Global Step 12600 and Step 4439: validation cost=0.00037
# Global Step 12650 and Step 4489: validation cost=0.00029
# Updated min validation loss!Saving model...
# Global Step 12700 and Step 4539: validation cost=0.00035
# Global Step 12750 and Step 4589: validation cost=0.00030
# Global Step 12800 and Step 4639: validation cost=0.00031
# Global Step 12850 and Step 4689: validation cost=0.00031
# Global Step 12900 and Step 4739: validation cost=0.00031
# Global Step 12950 and Step 4789: validation cost=0.00031
# Global Step 13000 and Step 4839: validation cost=0.00036
# Global Step 13050 and Step 4889: validation cost=0.00046
# Global Step 13100 and Step 4939: validation cost=0.00029
# Global Step 13150 and Step 4989: validation cost=0.00033
# Global Step 13200 and Step 5039: validation cost=0.00029
# Updated min validation loss!Saving model...
# Global Step 13250 and Step 5089: validation cost=0.00027
# Updated min validation loss!Saving model...
# Global Step 13300 and Step 5139: validation cost=0.00027
# Updated min validation loss!Saving model...
# Global Step 13350 and Step 5189: validation cost=0.00026
# Updated min validation loss!Saving model...
# Global Step 13400 and Step 5239: validation cost=0.00027
# Global Step 13450 and Step 5289: validation cost=0.00025
# Updated min validation loss!Saving model...
# Global Step 13500 and Step 5339: validation cost=0.00027
# Global Step 13550 and Step 5389: validation cost=0.00026
# Global Step 13600 and Step 5439: validation cost=0.00034
# Global Step 13650 and Step 5489: validation cost=0.00067
# Global Step 13700 and Step 5539: validation cost=0.00047
# Global Step 13750 and Step 5589: validation cost=0.00031
# Global Step 13800 and Step 5639: validation cost=0.00027
# Global Step 13850 and Step 5689: validation cost=0.00030
# Global Step 13900 and Step 5739: validation cost=0.00038
# Global Step 13950 and Step 5789: validation cost=0.00031
# Global Step 14000 and Step 5839: validation cost=0.00034
# Global Step 14050 and Step 5889: validation cost=0.00024
# Updated min validation loss!Saving model...
# Global Step 14100 and Step 5939: validation cost=0.00023
# Updated min validation loss!Saving model...
# Global Step 14150 and Step 5989: validation cost=0.00036
# Global Step 14200 and Step 6039: validation cost=0.00036
# Global Step 14250 and Step 6089: validation cost=0.00027
# Global Step 14300 and Step 6139: validation cost=0.00049
# Global Step 14350 and Step 6189: validation cost=0.00046
# Global Step 14400 and Step 6239: validation cost=0.00025
# Global Step 14450 and Step 6289: validation cost=0.00027
# Global Step 14500 and Step 6339: validation cost=0.00029
# Global Step 14550 and Step 6389: validation cost=0.00026
# Global Step 14600 and Step 6439: validation cost=0.00027
# Global Step 14650 and Step 6489: validation cost=0.00037
# Global Step 14700 and Step 6539: validation cost=0.00034
# Global Step 14750 and Step 6589: validation cost=0.00044
# Global Step 14800 and Step 6639: validation cost=0.00039
# Global Step 14850 and Step 6689: validation cost=0.00038
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 14900 and Step 0050: validation cost=0.00021
# Updated min validation loss!Saving model...
# Global Step 14950 and Step 0100: validation cost=0.00022
# Global Step 15000 and Step 0150: validation cost=0.00022
# Global Step 15050 and Step 0200: validation cost=0.00021
# Updated min validation loss!Saving model...
# Global Step 15100 and Step 0250: validation cost=0.00021
# Global Step 15150 and Step 0300: validation cost=0.00020
# Updated min validation loss!Saving model...
# Global Step 15200 and Step 0350: validation cost=0.00021
# Global Step 15250 and Step 0400: validation cost=0.00021
# Global Step 15300 and Step 0450: validation cost=0.00021
# Global Step 15350 and Step 0500: validation cost=0.00022
# Global Step 15400 and Step 0550: validation cost=0.00023
# Global Step 15450 and Step 0600: validation cost=0.00021
# Global Step 15500 and Step 0650: validation cost=0.00022
# Global Step 15550 and Step 0700: validation cost=0.00021
# Global Step 15600 and Step 0750: validation cost=0.00022
# Global Step 15650 and Step 0800: validation cost=0.00023
# Global Step 15700 and Step 0850: validation cost=0.00021
# Global Step 15750 and Step 0900: validation cost=0.00020
# Updated min validation loss!Saving model...
# Global Step 15800 and Step 0950: validation cost=0.00023
# Global Step 15850 and Step 1000: validation cost=0.00022
# Global Step 15900 and Step 1050: validation cost=0.00021
# Global Step 15950 and Step 1100: validation cost=0.00022
# Global Step 16000 and Step 1150: validation cost=0.00021
# Global Step 16050 and Step 1200: validation cost=0.00021
# Global Step 16100 and Step 1250: validation cost=0.00021
# Global Step 16150 and Step 1300: validation cost=0.00030
# Global Step 16200 and Step 1350: validation cost=0.00022
# Global Step 16250 and Step 1400: validation cost=0.00022
# Global Step 16300 and Step 1450: validation cost=0.00024
# Global Step 16350 and Step 1500: validation cost=0.00022
# Global Step 16400 and Step 1550: validation cost=0.00021
# Global Step 16450 and Step 1600: validation cost=0.00023
# Global Step 16500 and Step 1650: validation cost=0.00024
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 16550 and Step 0050: validation cost=0.00021
# Global Step 16600 and Step 0100: validation cost=0.00021
# Global Step 16650 and Step 0150: validation cost=0.00020
# Global Step 16700 and Step 0200: validation cost=0.00020
# Global Step 16750 and Step 0250: validation cost=0.00020
# Global Step 16800 and Step 0300: validation cost=0.00021
# Global Step 16850 and Step 0350: validation cost=0.00020
# Global Step 16900 and Step 0400: validation cost=0.00021
# Global Step 16950 and Step 0450: validation cost=0.00020
# Updated min validation loss!Saving model...
# Global Step 17000 and Step 0500: validation cost=0.00021
# Global Step 17050 and Step 0550: validation cost=0.00021
# Global Step 17100 and Step 0600: validation cost=0.00021
# Global Step 17150 and Step 0650: validation cost=0.00021
# Global Step 17200 and Step 0700: validation cost=0.00020
# Global Step 17250 and Step 0750: validation cost=0.00021
# Global Step 17300 and Step 0800: validation cost=0.00020
# Global Step 17350 and Step 0850: validation cost=0.00021
# Global Step 17400 and Step 0900: validation cost=0.00020
# Global Step 17450 and Step 0950: validation cost=0.00020
# Global Step 17500 and Step 1000: validation cost=0.00021
# Global Step 17550 and Step 1050: validation cost=0.00021
# Global Step 17600 and Step 1100: validation cost=0.00020
# Global Step 17650 and Step 1150: validation cost=0.00020
# Global Step 17700 and Step 1200: validation cost=0.00021
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 17750 and Step 0050: validation cost=0.00020
# Global Step 17800 and Step 0100: validation cost=0.00020
# Global Step 17850 and Step 0150: validation cost=0.00020
# Global Step 17900 and Step 0200: validation cost=0.00020
# Global Step 17950 and Step 0250: validation cost=0.00020
# Global Step 18000 and Step 0300: validation cost=0.00020
# Updated min validation loss!Saving model...
# Global Step 18050 and Step 0350: validation cost=0.00020
# Updated min validation loss!Saving model...
# Global Step 18100 and Step 0400: validation cost=0.00020
# Global Step 18150 and Step 0450: validation cost=0.00020
# Global Step 18200 and Step 0500: validation cost=0.00020
# Global Step 18250 and Step 0550: validation cost=0.00020
# Global Step 18300 and Step 0600: validation cost=0.00021
# Global Step 18350 and Step 0650: validation cost=0.00020
# Global Step 18400 and Step 0700: validation cost=0.00020
# Global Step 18450 and Step 0750: validation cost=0.00020
# Global Step 18500 and Step 0800: validation cost=0.00020
# Global Step 18550 and Step 0850: validation cost=0.00020
# Global Step 18600 and Step 0900: validation cost=0.00020
# Global Step 18650 and Step 0950: validation cost=0.00020
# Global Step 18700 and Step 1000: validation cost=0.00020
# Global Step 18750 and Step 1050: validation cost=0.00021
# Global Step 18800 and Step 1100: validation cost=0.00021
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 18850 and Step 0050: validation cost=0.00020
# Global Step 18900 and Step 0100: validation cost=0.00020
# Global Step 18950 and Step 0150: validation cost=0.00020
# Global Step 19000 and Step 0200: validation cost=0.00020
# Updated min validation loss!Saving model...
# Global Step 19050 and Step 0250: validation cost=0.00020
# Updated min validation loss!Saving model...
# Global Step 19100 and Step 0300: validation cost=0.00020
# Global Step 19150 and Step 0350: validation cost=0.00020
# Global Step 19200 and Step 0400: validation cost=0.00020
# Global Step 19250 and Step 0450: validation cost=0.00020
# Global Step 19300 and Step 0500: validation cost=0.00020
# Global Step 19350 and Step 0550: validation cost=0.00020
# Global Step 19400 and Step 0600: validation cost=0.00020
# Global Step 19450 and Step 0650: validation cost=0.00020
# Global Step 19500 and Step 0700: validation cost=0.00020
# Global Step 19550 and Step 0750: validation cost=0.00020
# Global Step 19600 and Step 0800: validation cost=0.00020
# Global Step 19650 and Step 0850: validation cost=0.00020
# Global Step 19700 and Step 0900: validation cost=0.00020
# Global Step 19750 and Step 0950: validation cost=0.00020
# Global Step 19800 and Step 1000: validation cost=0.00020
# Early Stopping!!!
# Restoring the best parameters...

# %%
w_pre = toy_net2_trainer.evaluate(ops=toy_data_net2.kernel_pre)
w_post = toy_net2_trainer.evaluate(ops=toy_data_net2.kernel_post)
w_post_post = toy_net2_trainer.evaluate(ops=toy_data_net2.kernel_post_post)
plt.plot(w_pre, label='ker_pre_init')
plt.plot(w_post, label='ker_post_init')
plt.plot(w_post_post, label='ker_post_post_init')
bias = toy_net2_trainer.evaluate(ops=toy_data_net2.bias)
plt.legend()
bias
# Out:
# 0.1179319
# /usr/local/lib/python3.5/dist-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
