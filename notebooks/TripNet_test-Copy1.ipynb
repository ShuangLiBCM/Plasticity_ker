# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from modelval import pairptl, network, trainer, dataset
from modelval.ArbDataGen import arb_w_gen

% matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Visualize kernel
from modelval.kernel import KernelGen
plt.figure(figsize=(5,3))
ker_test = KernelGen()
ker_test.kernel_pre = KernelGen().uni_exp_ker(side='left', tau=20, scale=0.1)
ker_test.kernel_post = KernelGen().uni_exp_ker(side='left', tau=20, scale=0.1)
ker_test.kernel_post_post = KernelGen().uni_exp_ker(side='left', tau=50, scale=0.1, if_shift=True)
plt.plot(ker_test.kernel_pre, label='ker_pre')
plt.plot(ker_test.kernel_post, label='ker_post')
plt.plot(ker_test.kernel_post_post, label='ker_post_post')
plt.legend()
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# Load data frame
data = pd.read_csv('/src/Plasticity_Ker/data/kernel_training_data_auto.csv')
data['train_len'] = data['ptl_occ'] / data['ptl_freq']
data.head()
# Out:
#    ptl_idx  pre_spk_num  pre_spk_freq  post_spk_num  post_spk_freq  ptl_occ  \
# 0        1            1             0             1              0       60
# 1        1            1             0             1              0       60
# 2        1            1             0             1              0       60
# 3        1            1             0             1              0       60
# 4        1            1             0             1              0       60
#
#    ptl_freq         dt1  dt2  dt3    dw_mean  dw_ste  train_len
# 0       1.0 -102.898046  0.0    0  -1.322590     0.0       60.0
# 1       1.0  -75.579896  0.0    0   2.674768     0.0       60.0
# 2       1.0  -80.871473  0.0    0 -12.696449     0.0       60.0
# 3       1.0  -67.562239  0.0    0   0.231446     0.0       60.0
# 4       1.0  -63.553410  0.0    0  -0.990216     0.0       60.0

# %%
# Generate data
ptl_list = [2,3,4]
spk_len = int(data[data['ptl_idx'].isin(ptl_list)]['train_len'].max() * 1000 / ker_test.reso_kernel)
spk_pairs, targets = arb_w_gen(df=data, ptl_list=ptl_list, spk_len=spk_len, kernel=ker_test, aug_times=10, net_type='triplet')
# targets = np.expand_dims(np.expand_dims(targets, axis=1), axis=2)

# %%
# Create the network
ground_truth_init = 0
toy_data_net2 = network.TripNet(kernel=ker_test, ground_truth_init=ground_truth_init, n_input=spk_pairs.shape[1])

# %%
# Create the trainer
save_dir= '/src/Plasticity_Ker/model/TripNet_ptl2-4_toy'
toy_net2_trainer = trainer.Trainer(toy_data_net2.loss, input_name=toy_data_net2.inputs, target_name=toy_data_net2.target, save_dir=save_dir, optimizer_config={'learning_rate': toy_data_net2.lr})

# %%
# Obtain the training and validation data
from sklearn.model_selection import train_test_split

X_train, X_vali, y_train, y_vali = train_test_split(spk_pairs, targets, test_size=0.1)
train_data = dataset.Dataset(X_train, y_train)
vali_data = dataset.Dataset(X_vali, y_vali)

# %%
w_pre = toy_net2_trainer.evaluate(ops=toy_data_net2.kernel_pre)
w_post = toy_net2_trainer.evaluate(ops=toy_data_net2.kernel_post)
w_post_post = toy_net2_trainer.evaluate(ops=toy_data_net2.kernel_post_post)
plt.plot(w_pre, label='ker_pre_init')
plt.plot(w_post, label='ker_post_init')
plt.plot(w_post_post, label='ker_post_post_init')
bias = toy_net2_trainer.evaluate(ops=toy_data_net2.bias)
plt.legend()
bias
# Out:
# 0.0
# /usr/local/lib/python3.5/dist-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# Learn the kernel from random initialization
learning_rate = 0.001
iterations = 5
min_error = -1
for i in range(iterations):
    toy_net2_trainer.train(train_data, vali_data, batch_size=128, min_error=min_error, feed_dict={toy_data_net2.lr: learning_rate})
    learning_rate = learning_rate/3
# Out:
# Initial validation cost=266.38489
# Global Step 0150 and Step 0150: validation cost=21.20423
# Updated min validation loss!Saving model...
# Global Step 0200 and Step 0200: validation cost=17.63173
# Updated min validation loss!Saving model...
# Global Step 0250 and Step 0250: validation cost=15.45705
# Updated min validation loss!Saving model...
# Global Step 0300 and Step 0300: validation cost=13.71221
# Updated min validation loss!Saving model...
# Global Step 0350 and Step 0350: validation cost=12.26863
# Updated min validation loss!Saving model...
# Global Step 0400 and Step 0400: validation cost=11.07002
# Updated min validation loss!Saving model...
# Global Step 0450 and Step 0450: validation cost=10.12027
# Updated min validation loss!Saving model...
# Global Step 0500 and Step 0500: validation cost=9.27847
# Updated min validation loss!Saving model...
# Global Step 0550 and Step 0550: validation cost=8.58211
# Updated min validation loss!Saving model...
# Global Step 0600 and Step 0600: validation cost=7.96671
# Updated min validation loss!Saving model...
# Global Step 0650 and Step 0650: validation cost=7.44139
# Updated min validation loss!Saving model...
# Global Step 0700 and Step 0700: validation cost=6.97107
# Updated min validation loss!Saving model...
# Global Step 0750 and Step 0750: validation cost=6.54294
# Updated min validation loss!Saving model...
# Global Step 0800 and Step 0800: validation cost=6.15720
# Updated min validation loss!Saving model...
# Global Step 0850 and Step 0850: validation cost=5.76268
# Updated min validation loss!Saving model...
# Global Step 0900 and Step 0900: validation cost=5.41390
# Updated min validation loss!Saving model...
# Global Step 0950 and Step 0950: validation cost=5.08521
# Updated min validation loss!Saving model...
# Global Step 1000 and Step 1000: validation cost=4.78837
# Updated min validation loss!Saving model...
# Global Step 1050 and Step 1050: validation cost=4.47759
# Updated min validation loss!Saving model...
# Global Step 1100 and Step 1100: validation cost=4.20489
# Updated min validation loss!Saving model...
# Global Step 1150 and Step 1150: validation cost=3.95389
# Updated min validation loss!Saving model...
# Global Step 1200 and Step 1200: validation cost=3.70417
# Updated min validation loss!Saving model...
# Global Step 1250 and Step 1250: validation cost=3.46260
# Updated min validation loss!Saving model...
# Global Step 1300 and Step 1300: validation cost=3.26973
# Updated min validation loss!Saving model...
# Global Step 1350 and Step 1350: validation cost=3.06983
# Updated min validation loss!Saving model...
# Global Step 1400 and Step 1400: validation cost=2.89385
# Updated min validation loss!Saving model...
# Global Step 1450 and Step 1450: validation cost=2.72746
# Updated min validation loss!Saving model...
# Global Step 1500 and Step 1500: validation cost=2.57691
# Updated min validation loss!Saving model...
# Global Step 1550 and Step 1550: validation cost=2.42027
# Updated min validation loss!Saving model...
# Global Step 1600 and Step 1600: validation cost=2.28688
# Updated min validation loss!Saving model...
# Global Step 1650 and Step 1650: validation cost=2.16730
# Updated min validation loss!Saving model...
# Global Step 1700 and Step 1700: validation cost=2.04910
# Updated min validation loss!Saving model...
# Global Step 1750 and Step 1750: validation cost=1.94163
# Updated min validation loss!Saving model...
# Global Step 1800 and Step 1800: validation cost=1.84083
# Updated min validation loss!Saving model...
# Global Step 1850 and Step 1850: validation cost=1.75002
# Updated min validation loss!Saving model...
# Global Step 1900 and Step 1900: validation cost=1.64738
# Updated min validation loss!Saving model...
# Global Step 1950 and Step 1950: validation cost=1.56660
# Updated min validation loss!Saving model...
# Global Step 2000 and Step 2000: validation cost=1.47906
# Updated min validation loss!Saving model...
# Global Step 2050 and Step 2050: validation cost=1.40524
# Updated min validation loss!Saving model...
# Global Step 2100 and Step 2100: validation cost=1.33446
# Updated min validation loss!Saving model...
# Global Step 2150 and Step 2150: validation cost=1.26420
# Updated min validation loss!Saving model...
# Global Step 2200 and Step 2200: validation cost=1.19592
# Updated min validation loss!Saving model...
# Global Step 2250 and Step 2250: validation cost=1.13656
# Updated min validation loss!Saving model...
# Global Step 2300 and Step 2300: validation cost=1.07120
# Updated min validation loss!Saving model...
# Global Step 2350 and Step 2350: validation cost=1.01644
# Updated min validation loss!Saving model...
# Global Step 2400 and Step 2400: validation cost=0.96334
# Updated min validation loss!Saving model...
# Global Step 2450 and Step 2450: validation cost=0.91246
# Updated min validation loss!Saving model...
# Global Step 2500 and Step 2500: validation cost=0.85943
# Updated min validation loss!Saving model...
# Global Step 2550 and Step 2550: validation cost=0.81571
# Updated min validation loss!Saving model...
# Global Step 2600 and Step 2600: validation cost=0.77301
# Updated min validation loss!Saving model...
# Global Step 2650 and Step 2650: validation cost=0.72709
# Updated min validation loss!Saving model...
# Global Step 2700 and Step 2700: validation cost=0.69074
# Updated min validation loss!Saving model...
# Global Step 2750 and Step 2750: validation cost=0.65213
# Updated min validation loss!Saving model...
# Global Step 2800 and Step 2800: validation cost=0.61421
# Updated min validation loss!Saving model...
# Global Step 2850 and Step 2850: validation cost=0.58214
# Updated min validation loss!Saving model...
# Global Step 2900 and Step 2900: validation cost=0.55191
# Updated min validation loss!Saving model...
# Global Step 2950 and Step 2950: validation cost=0.51810
# Updated min validation loss!Saving model...
# Global Step 3000 and Step 3000: validation cost=0.48834
# Updated min validation loss!Saving model...
# Global Step 3050 and Step 3050: validation cost=0.46026
# Updated min validation loss!Saving model...
# Global Step 3100 and Step 3100: validation cost=0.43394
# Updated min validation loss!Saving model...
# Global Step 3150 and Step 3150: validation cost=0.41141
# Updated min validation loss!Saving model...
# Global Step 3200 and Step 3200: validation cost=0.38741
# Updated min validation loss!Saving model...
# Global Step 3250 and Step 3250: validation cost=0.36948
# Updated min validation loss!Saving model...
# Global Step 3300 and Step 3300: validation cost=0.34717
# Updated min validation loss!Saving model...
# Global Step 3350 and Step 3350: validation cost=0.33092
# Updated min validation loss!Saving model...
# Global Step 3400 and Step 3400: validation cost=0.30764
# Updated min validation loss!Saving model...
# Global Step 3450 and Step 3450: validation cost=0.29162
# Updated min validation loss!Saving model...
# Global Step 3500 and Step 3500: validation cost=0.27482
# Updated min validation loss!Saving model...
# Global Step 3550 and Step 3550: validation cost=0.25831
# Updated min validation loss!Saving model...
# Global Step 3600 and Step 3600: validation cost=0.24641
# Updated min validation loss!Saving model...
# Global Step 3650 and Step 3650: validation cost=0.23269
# Updated min validation loss!Saving model...
# Global Step 3700 and Step 3700: validation cost=0.22032
# Updated min validation loss!Saving model...
# Global Step 3750 and Step 3750: validation cost=0.20820
# Updated min validation loss!Saving model...
# Global Step 3800 and Step 3800: validation cost=0.19716
# Updated min validation loss!Saving model...
# Global Step 3850 and Step 3850: validation cost=0.18349
# Updated min validation loss!Saving model...
# Global Step 3900 and Step 3900: validation cost=0.17652
# Updated min validation loss!Saving model...
# Global Step 3950 and Step 3950: validation cost=0.16654
# Updated min validation loss!Saving model...
# Global Step 4000 and Step 4000: validation cost=0.15647
# Updated min validation loss!Saving model...
# Global Step 4050 and Step 4050: validation cost=0.14868
# Updated min validation loss!Saving model...
# Global Step 4100 and Step 4100: validation cost=0.13996
# Updated min validation loss!Saving model...
# Global Step 4150 and Step 4150: validation cost=0.13345
# Updated min validation loss!Saving model...
# Global Step 4200 and Step 4200: validation cost=0.12713
# Updated min validation loss!Saving model...
# Global Step 4250 and Step 4250: validation cost=0.12068
# Updated min validation loss!Saving model...
# Global Step 4300 and Step 4300: validation cost=0.11525
# Updated min validation loss!Saving model...
# Global Step 4350 and Step 4350: validation cost=0.11040
# Updated min validation loss!Saving model...
# Global Step 4400 and Step 4400: validation cost=0.10423
# Updated min validation loss!Saving model...
# Global Step 4450 and Step 4450: validation cost=0.10083
# Updated min validation loss!Saving model...
# Global Step 4500 and Step 4500: validation cost=0.09561
# Updated min validation loss!Saving model...
# Global Step 4550 and Step 4550: validation cost=0.09162
# Updated min validation loss!Saving model...
# Global Step 4600 and Step 4600: validation cost=0.08641
# Updated min validation loss!Saving model...
# Global Step 4650 and Step 4650: validation cost=0.08346
# Updated min validation loss!Saving model...
# Global Step 4700 and Step 4700: validation cost=0.08001
# Updated min validation loss!Saving model...
# Global Step 4750 and Step 4750: validation cost=0.07751
# Updated min validation loss!Saving model...
# Global Step 4800 and Step 4800: validation cost=0.07420
# Updated min validation loss!Saving model...
# Global Step 4850 and Step 4850: validation cost=0.07178
# Updated min validation loss!Saving model...
# Global Step 4900 and Step 4900: validation cost=0.06865
# Updated min validation loss!Saving model...
# Global Step 4950 and Step 4950: validation cost=0.06580
# Updated min validation loss!Saving model...
# Global Step 5000 and Step 5000: validation cost=0.06305
# Updated min validation loss!Saving model...
# Global Step 5050 and Step 5050: validation cost=0.06156
# Updated min validation loss!Saving model...
# Global Step 5100 and Step 5100: validation cost=0.05971
# Updated min validation loss!Saving model...
# Global Step 5150 and Step 5150: validation cost=0.05718
# Updated min validation loss!Saving model...
# Global Step 5200 and Step 5200: validation cost=0.05552
# Updated min validation loss!Saving model...
# Global Step 5250 and Step 5250: validation cost=0.05488
# Updated min validation loss!Saving model...
# Global Step 5300 and Step 5300: validation cost=0.05356
# Updated min validation loss!Saving model...
# Global Step 5350 and Step 5350: validation cost=0.05124
# Updated min validation loss!Saving model...
# Global Step 5400 and Step 5400: validation cost=0.05090
# Updated min validation loss!Saving model...
# Global Step 5450 and Step 5450: validation cost=0.04921
# Updated min validation loss!Saving model...
# Global Step 5500 and Step 5500: validation cost=0.04770
# Updated min validation loss!Saving model...
# Global Step 5550 and Step 5550: validation cost=0.04574
# Updated min validation loss!Saving model...
# Global Step 5600 and Step 5600: validation cost=0.04506
# Updated min validation loss!Saving model...
# Global Step 5650 and Step 5650: validation cost=0.04389
# Updated min validation loss!Saving model...
# Global Step 5700 and Step 5700: validation cost=0.04193
# Updated min validation loss!Saving model...
# Global Step 5750 and Step 5750: validation cost=0.04141
# Updated min validation loss!Saving model...
# Global Step 5800 and Step 5800: validation cost=0.03961
# Updated min validation loss!Saving model...
# Global Step 5850 and Step 5850: validation cost=0.03865
# Updated min validation loss!Saving model...
# Global Step 5900 and Step 5900: validation cost=0.03755
# Updated min validation loss!Saving model...
# Global Step 5950 and Step 5950: validation cost=0.03695
# Updated min validation loss!Saving model...
# Global Step 6000 and Step 6000: validation cost=0.03600
# Updated min validation loss!Saving model...
# Global Step 6050 and Step 6050: validation cost=0.03497
# Updated min validation loss!Saving model...
# Global Step 6100 and Step 6100: validation cost=0.03363
# Updated min validation loss!Saving model...
# Global Step 6150 and Step 6150: validation cost=0.03289
# Updated min validation loss!Saving model...
# Global Step 6200 and Step 6200: validation cost=0.03259
# Updated min validation loss!Saving model...
# Global Step 6250 and Step 6250: validation cost=0.03092
# Updated min validation loss!Saving model...
# Global Step 6300 and Step 6300: validation cost=0.03074
# Updated min validation loss!Saving model...
# Global Step 6350 and Step 6350: validation cost=0.02925
# Updated min validation loss!Saving model...
# Global Step 6400 and Step 6400: validation cost=0.02819
# Updated min validation loss!Saving model...
# Global Step 6450 and Step 6450: validation cost=0.02744
# Updated min validation loss!Saving model...
# Global Step 6500 and Step 6500: validation cost=0.02659
# Updated min validation loss!Saving model...
# Global Step 6550 and Step 6550: validation cost=0.02547
# Updated min validation loss!Saving model...
# Global Step 6600 and Step 6600: validation cost=0.02459
# Updated min validation loss!Saving model...
# Global Step 6650 and Step 6650: validation cost=0.02399
# Updated min validation loss!Saving model...
# Global Step 6700 and Step 6700: validation cost=0.02300
# Updated min validation loss!Saving model...
# Global Step 6750 and Step 6750: validation cost=0.02221
# Updated min validation loss!Saving model...
# Global Step 6800 and Step 6800: validation cost=0.02160
# Updated min validation loss!Saving model...
# Global Step 6850 and Step 6850: validation cost=0.02121
# Updated min validation loss!Saving model...
# Global Step 6900 and Step 6900: validation cost=0.02045
# Updated min validation loss!Saving model...
# Global Step 6950 and Step 6950: validation cost=0.01943
# Updated min validation loss!Saving model...
# Global Step 7000 and Step 7000: validation cost=0.01905
# Updated min validation loss!Saving model...
# Global Step 7050 and Step 7050: validation cost=0.01820
# Updated min validation loss!Saving model...
# Global Step 7100 and Step 7100: validation cost=0.01754
# Updated min validation loss!Saving model...
# Global Step 7150 and Step 7150: validation cost=0.01678
# Updated min validation loss!Saving model...
# Global Step 7200 and Step 7200: validation cost=0.01635
# Updated min validation loss!Saving model...
# Global Step 7250 and Step 7250: validation cost=0.01543
# Updated min validation loss!Saving model...
# Global Step 7300 and Step 7300: validation cost=0.01502
# Updated min validation loss!Saving model...
# Global Step 7350 and Step 7350: validation cost=0.01447
# Updated min validation loss!Saving model...
# Global Step 7400 and Step 7400: validation cost=0.01360
# Updated min validation loss!Saving model...
# Global Step 7450 and Step 7450: validation cost=0.01279
# Updated min validation loss!Saving model...
# Global Step 7500 and Step 7500: validation cost=0.01216
# Updated min validation loss!Saving model...
# Global Step 7550 and Step 7550: validation cost=0.01167
# Updated min validation loss!Saving model...
# Global Step 7600 and Step 7600: validation cost=0.01150
# Updated min validation loss!Saving model...
# Global Step 7650 and Step 7650: validation cost=0.01060
# Updated min validation loss!Saving model...
# Global Step 7700 and Step 7700: validation cost=0.01020
# Updated min validation loss!Saving model...
# Global Step 7750 and Step 7750: validation cost=0.00957
# Updated min validation loss!Saving model...
# Global Step 7800 and Step 7800: validation cost=0.00931
# Updated min validation loss!Saving model...
# Global Step 7850 and Step 7850: validation cost=0.00874
# Updated min validation loss!Saving model...
# Global Step 7900 and Step 7900: validation cost=0.00803
# Updated min validation loss!Saving model...
# Global Step 7950 and Step 7950: validation cost=0.00795
# Updated min validation loss!Saving model...
# Global Step 8000 and Step 8000: validation cost=0.00756
# Updated min validation loss!Saving model...
# Global Step 8050 and Step 8050: validation cost=0.00703
# Updated min validation loss!Saving model...
# Global Step 8100 and Step 8100: validation cost=0.00650
# Updated min validation loss!Saving model...
# Global Step 8150 and Step 8150: validation cost=0.00613
# Updated min validation loss!Saving model...
# Global Step 8200 and Step 8200: validation cost=0.00607
# Updated min validation loss!Saving model...
# Global Step 8250 and Step 8250: validation cost=0.00558
# Updated min validation loss!Saving model...
# Global Step 8300 and Step 8300: validation cost=0.00529
# Updated min validation loss!Saving model...
# Global Step 8350 and Step 8350: validation cost=0.00493
# Updated min validation loss!Saving model...
# Global Step 8400 and Step 8400: validation cost=0.00440
# Updated min validation loss!Saving model...
# Global Step 8450 and Step 8450: validation cost=0.00433
# Updated min validation loss!Saving model...
# Global Step 8500 and Step 8500: validation cost=0.00388
# Updated min validation loss!Saving model...
# Global Step 8550 and Step 8550: validation cost=0.00353
# Updated min validation loss!Saving model...
# Global Step 8600 and Step 8600: validation cost=0.00350
# Updated min validation loss!Saving model...
# Global Step 8650 and Step 8650: validation cost=0.00339
# Updated min validation loss!Saving model...
# Global Step 8700 and Step 8700: validation cost=0.00299
# Updated min validation loss!Saving model...
# Global Step 8750 and Step 8750: validation cost=0.00267
# Updated min validation loss!Saving model...
# Global Step 8800 and Step 8800: validation cost=0.00231
# Updated min validation loss!Saving model...
# Global Step 8850 and Step 8850: validation cost=0.00230
# Updated min validation loss!Saving model...
# Global Step 8900 and Step 8900: validation cost=0.00213
# Updated min validation loss!Saving model...
# Global Step 8950 and Step 8950: validation cost=0.00192
# Updated min validation loss!Saving model...
# Global Step 9000 and Step 9000: validation cost=0.00179
# Updated min validation loss!Saving model...
# Global Step 9050 and Step 9050: validation cost=0.00167
# Updated min validation loss!Saving model...
# Global Step 9100 and Step 9100: validation cost=0.00146
# Updated min validation loss!Saving model...
# Global Step 9150 and Step 9150: validation cost=0.00137
# Updated min validation loss!Saving model...
# Global Step 9200 and Step 9200: validation cost=0.00130
# Updated min validation loss!Saving model...
# Global Step 9250 and Step 9250: validation cost=0.00120
# Updated min validation loss!Saving model...
# Global Step 9300 and Step 9300: validation cost=0.00103
# Updated min validation loss!Saving model...
# Global Step 9350 and Step 9350: validation cost=0.00092
# Updated min validation loss!Saving model...
# Global Step 9400 and Step 9400: validation cost=0.00100
# Global Step 9450 and Step 9450: validation cost=0.00080
# Updated min validation loss!Saving model...
# Global Step 9500 and Step 9500: validation cost=0.00070
# Updated min validation loss!Saving model...
# Global Step 9550 and Step 9550: validation cost=0.00060
# Updated min validation loss!Saving model...
# Global Step 9600 and Step 9600: validation cost=0.00057
# Updated min validation loss!Saving model...
# Global Step 9650 and Step 9650: validation cost=0.00048
# Updated min validation loss!Saving model...
# Global Step 9700 and Step 9700: validation cost=0.00043
# Updated min validation loss!Saving model...
# Global Step 9750 and Step 9750: validation cost=0.00036
# Updated min validation loss!Saving model...
# Global Step 9800 and Step 9800: validation cost=0.00034
# Updated min validation loss!Saving model...
# Global Step 9850 and Step 9850: validation cost=0.00037
# Global Step 9900 and Step 9900: validation cost=0.00027
# Updated min validation loss!Saving model...
# Global Step 9950 and Step 9950: validation cost=0.00026
# Updated min validation loss!Saving model...
# Global Step 10000 and Step 10000: validation cost=0.00019
# Updated min validation loss!Saving model...
# Global Step 10050 and Step 10050: validation cost=0.00017
# Updated min validation loss!Saving model...
# Global Step 10100 and Step 10100: validation cost=0.00016
# Updated min validation loss!Saving model...
# Global Step 10150 and Step 10150: validation cost=0.00014
# Updated min validation loss!Saving model...
# Global Step 10200 and Step 10200: validation cost=0.00013
# Updated min validation loss!Saving model...
# Global Step 10250 and Step 10250: validation cost=0.00010
# Updated min validation loss!Saving model...
# Global Step 10300 and Step 10300: validation cost=0.00009
# Updated min validation loss!Saving model...
# Global Step 10350 and Step 10350: validation cost=0.00008
# Updated min validation loss!Saving model...
# Global Step 10400 and Step 10400: validation cost=0.00007
# Updated min validation loss!Saving model...
# Global Step 10450 and Step 10450: validation cost=0.00006
# Updated min validation loss!Saving model...
# Global Step 10500 and Step 10500: validation cost=0.00005
# Updated min validation loss!Saving model...
# Global Step 10550 and Step 10550: validation cost=0.00004
# Updated min validation loss!Saving model...
# Global Step 10600 and Step 10600: validation cost=0.00004
# Updated min validation loss!Saving model...
# Global Step 10650 and Step 10650: validation cost=0.00003
# Updated min validation loss!Saving model...
# Global Step 10700 and Step 10700: validation cost=0.00003
# Updated min validation loss!Saving model...
# Global Step 10750 and Step 10750: validation cost=0.00003
# Updated min validation loss!Saving model...
# Global Step 10800 and Step 10800: validation cost=0.00002
# Updated min validation loss!Saving model...
# Global Step 10850 and Step 10850: validation cost=0.00002
# Updated min validation loss!Saving model...
# Global Step 10900 and Step 10900: validation cost=0.00002
# Updated min validation loss!Saving model...
# Global Step 10950 and Step 10950: validation cost=0.00001
# Updated min validation loss!Saving model...
# Global Step 11000 and Step 11000: validation cost=0.00001
# Updated min validation loss!Saving model...
# Global Step 11050 and Step 11050: validation cost=0.00001
# Updated min validation loss!Saving model...
# Global Step 11100 and Step 11100: validation cost=0.00001
# Updated min validation loss!Saving model...
# Global Step 11150 and Step 11150: validation cost=0.00001
# Updated min validation loss!Saving model...
# Global Step 11200 and Step 11200: validation cost=0.00001
# Updated min validation loss!Saving model...
# Global Step 11250 and Step 11250: validation cost=0.00001
# Updated min validation loss!Saving model...
# Global Step 11300 and Step 11300: validation cost=0.00000
# Updated min validation loss!Saving model...
# Global Step 11350 and Step 11350: validation cost=0.00000
# Global Step 11400 and Step 11400: validation cost=0.00000
# Updated min validation loss!Saving model...
# Global Step 11450 and Step 11450: validation cost=0.00001
# Global Step 11500 and Step 11500: validation cost=0.00001
# Global Step 11550 and Step 11550: validation cost=0.00000
# Updated min validation loss!Saving model...
# Global Step 11600 and Step 11600: validation cost=0.00000
# Updated min validation loss!Saving model...
# Global Step 11650 and Step 11650: validation cost=0.00000
# Global Step 11700 and Step 11700: validation cost=0.00000
# Global Step 11750 and Step 11750: validation cost=0.00001
# Global Step 11800 and Step 11800: validation cost=0.00000
# Updated min validation loss!Saving model...
# Global Step 11850 and Step 11850: validation cost=0.00000
# Global Step 11900 and Step 11900: validation cost=0.00000
# Global Step 11950 and Step 11950: validation cost=0.00000
# Global Step 12000 and Step 12000: validation cost=0.00001
# Global Step 12050 and Step 12050: validation cost=0.00000
# Global Step 12100 and Step 12100: validation cost=0.00000
# Global Step 12150 and Step 12150: validation cost=0.00000
# Global Step 12200 and Step 12200: validation cost=0.00000
# Global Step 12250 and Step 12250: validation cost=0.00003
# Global Step 12300 and Step 12300: validation cost=0.00002
# Global Step 12350 and Step 12350: validation cost=0.00001
# Global Step 12400 and Step 12400: validation cost=0.00000
# Global Step 12450 and Step 12450: validation cost=0.00000
# Global Step 12500 and Step 12500: validation cost=0.00001
# Global Step 12550 and Step 12550: validation cost=0.00001
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 12600 and Step 0050: validation cost=0.00000
# Updated min validation loss!Saving model...
# Global Step 12650 and Step 0100: validation cost=0.00000
# Updated min validation loss!Saving model...
# Global Step 12700 and Step 0150: validation cost=0.00000
# Updated min validation loss!Saving model...
# Global Step 12750 and Step 0200: validation cost=0.00000
# Updated min validation loss!Saving model...
# Global Step 12800 and Step 0250: validation cost=0.00000
# Global Step 12850 and Step 0300: validation cost=0.00000
# Global Step 12900 and Step 0350: validation cost=0.00000
# Global Step 12950 and Step 0400: validation cost=0.00000
# Global Step 13000 and Step 0450: validation cost=0.00000
# Global Step 13050 and Step 0500: validation cost=0.00000
# Updated min validation loss!Saving model...
# Global Step 13100 and Step 0550: validation cost=0.00000
# Global Step 13150 and Step 0600: validation cost=0.00000
# Updated min validation loss!Saving model...
# Global Step 13200 and Step 0650: validation cost=0.00000
# Global Step 13250 and Step 0700: validation cost=0.00000
# Updated min validation loss!Saving model...
# Global Step 13300 and Step 0750: validation cost=0.00000
# Global Step 13350 and Step 0800: validation cost=0.00000
# Updated min validation loss!Saving model...
# Global Step 13400 and Step 0850: validation cost=0.00000
# Updated min validation loss!Saving model...
# Global Step 13450 and Step 0900: validation cost=0.00000
# Global Step 13500 and Step 0950: validation cost=0.00000
# Global Step 13550 and Step 1000: validation cost=0.00000
# Global Step 13600 and Step 1050: validation cost=0.00000
# Global Step 13650 and Step 1100: validation cost=0.00000
# Global Step 13700 and Step 1150: validation cost=0.00000
# Global Step 13750 and Step 1200: validation cost=0.00000
# Updated min validation loss!Saving model...
# Global Step 13800 and Step 1250: validation cost=0.00000
# Global Step 13850 and Step 1300: validation cost=0.00000
# Global Step 13900 and Step 1350: validation cost=0.00000
# Global Step 13950 and Step 1400: validation cost=0.00000
# Global Step 14000 and Step 1450: validation cost=0.00000
# Global Step 14050 and Step 1500: validation cost=0.00000
# Updated min validation loss!Saving model...
# Global Step 14100 and Step 1550: validation cost=0.00000
# Global Step 14150 and Step 1600: validation cost=0.00000
# Global Step 14200 and Step 1650: validation cost=0.00000
# Global Step 14250 and Step 1700: validation cost=0.00000
# Global Step 14300 and Step 1750: validation cost=0.00000
# Global Step 14350 and Step 1800: validation cost=0.00000
# Global Step 14400 and Step 1850: validation cost=0.00000
# Global Step 14450 and Step 1900: validation cost=0.00000
# Global Step 14500 and Step 1950: validation cost=0.00000
# Global Step 14550 and Step 2000: validation cost=0.00000
# Global Step 14600 and Step 2050: validation cost=0.00000
# Global Step 14650 and Step 2100: validation cost=0.00000
# Global Step 14700 and Step 2150: validation cost=0.00000
# Global Step 14750 and Step 2200: validation cost=0.00000
# Global Step 14800 and Step 2250: validation cost=0.00000
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 14850 and Step 0050: validation cost=0.00000
# Global Step 14900 and Step 0100: validation cost=0.00000
# Updated min validation loss!Saving model...
# Global Step 14950 and Step 0150: validation cost=0.00000
# Global Step 15000 and Step 0200: validation cost=0.00000
# Updated min validation loss!Saving model...
# Global Step 15050 and Step 0250: validation cost=0.00000
# Global Step 15100 and Step 0300: validation cost=0.00000
# Updated min validation loss!Saving model...
# Global Step 15150 and Step 0350: validation cost=0.00000
# Global Step 15200 and Step 0400: validation cost=0.00000
# Global Step 15250 and Step 0450: validation cost=0.00000
# Global Step 15300 and Step 0500: validation cost=0.00000
# Global Step 15350 and Step 0550: validation cost=0.00000
# Global Step 15400 and Step 0600: validation cost=0.00000
# Global Step 15450 and Step 0650: validation cost=0.00000
# Updated min validation loss!Saving model...
# Global Step 15500 and Step 0700: validation cost=0.00000
# Global Step 15550 and Step 0750: validation cost=0.00000
# Global Step 15600 and Step 0800: validation cost=0.00000
# Global Step 15650 and Step 0850: validation cost=0.00000
# Global Step 15700 and Step 0900: validation cost=0.00000
# Updated min validation loss!Saving model...
# Global Step 15750 and Step 0950: validation cost=0.00000
# Global Step 15800 and Step 1000: validation cost=0.00000
# Global Step 15850 and Step 1050: validation cost=0.00000
# Global Step 15900 and Step 1100: validation cost=0.00000
# Global Step 15950 and Step 1150: validation cost=0.00000
# Global Step 16000 and Step 1200: validation cost=0.00000
# Global Step 16050 and Step 1250: validation cost=0.00000
# Global Step 16100 and Step 1300: validation cost=0.00000
# Global Step 16150 and Step 1350: validation cost=0.00000
# Updated min validation loss!Saving model...
# Global Step 16200 and Step 1400: validation cost=0.00000
# Global Step 16250 and Step 1450: validation cost=0.00000
# Global Step 16300 and Step 1500: validation cost=0.00000
# Global Step 16350 and Step 1550: validation cost=0.00000
# Global Step 16400 and Step 1600: validation cost=0.00000
# Global Step 16450 and Step 1650: validation cost=0.00000
# Global Step 16500 and Step 1700: validation cost=0.00000
# Global Step 16550 and Step 1750: validation cost=0.00000
# Global Step 16600 and Step 1800: validation cost=0.00000
# Global Step 16650 and Step 1850: validation cost=0.00000
# Global Step 16700 and Step 1900: validation cost=0.00000
# Global Step 16750 and Step 1950: validation cost=0.00000
# Global Step 16800 and Step 2000: validation cost=0.00000
# Global Step 16850 and Step 2050: validation cost=0.00000
# Global Step 16900 and Step 2100: validation cost=0.00000
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 16950 and Step 0050: validation cost=0.00000
# Global Step 17000 and Step 0100: validation cost=0.00000
# Global Step 17050 and Step 0150: validation cost=0.00000
# Global Step 17100 and Step 0200: validation cost=0.00000
# Global Step 17150 and Step 0250: validation cost=0.00000
# Updated min validation loss!Saving model...
# Global Step 17200 and Step 0300: validation cost=0.00000
# Global Step 17250 and Step 0350: validation cost=0.00000
# Global Step 17300 and Step 0400: validation cost=0.00000
# Global Step 17350 and Step 0450: validation cost=0.00000
# Global Step 17400 and Step 0500: validation cost=0.00000
# Global Step 17450 and Step 0550: validation cost=0.00000
# Global Step 17500 and Step 0600: validation cost=0.00000
# Global Step 17550 and Step 0650: validation cost=0.00000
# Global Step 17600 and Step 0700: validation cost=0.00000
# Global Step 17650 and Step 0750: validation cost=0.00000
# Global Step 17700 and Step 0800: validation cost=0.00000
# Global Step 17750 and Step 0850: validation cost=0.00000
# Global Step 17800 and Step 0900: validation cost=0.00000
# Global Step 17850 and Step 0950: validation cost=0.00000
# Global Step 17900 and Step 1000: validation cost=0.00000
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 17950 and Step 0050: validation cost=0.00000
# Global Step 18000 and Step 0100: validation cost=0.00000
# Global Step 18050 and Step 0150: validation cost=0.00000
# Global Step 18100 and Step 0200: validation cost=0.00000
# Global Step 18150 and Step 0250: validation cost=0.00000
# Global Step 18200 and Step 0300: validation cost=0.00000
# Global Step 18250 and Step 0350: validation cost=0.00000
# Global Step 18300 and Step 0400: validation cost=0.00000
# Global Step 18350 and Step 0450: validation cost=0.00000
# Global Step 18400 and Step 0500: validation cost=0.00000
# Global Step 18450 and Step 0550: validation cost=0.00000
# Global Step 18500 and Step 0600: validation cost=0.00000
# Global Step 18550 and Step 0650: validation cost=0.00000
# Global Step 18600 and Step 0700: validation cost=0.00000
# Global Step 18650 and Step 0750: validation cost=0.00000
# Early Stopping!!!
# Restoring the best parameters...

# %%
w_pre = toy_net2_trainer.evaluate(ops=toy_data_net2.kernel_pre)
w_post = toy_net2_trainer.evaluate(ops=toy_data_net2.kernel_post)
w_post_post = toy_net2_trainer.evaluate(ops=toy_data_net2.kernel_post_post)
plt.plot(w_pre, label='ker_pre_init')
plt.plot(w_post, label='ker_post_init')
plt.plot(w_post_post, label='ker_post_post_init')
bias = toy_net2_trainer.evaluate(ops=toy_data_net2.bias)
plt.legend()
bias
# Out:
# 0.082035698
# /usr/local/lib/python3.5/dist-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
