# %% [markdown]
# Test the validation schema

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datajoint as dj 
import modelval.hyper_search_hippo_schema as sk_hyperpara

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Connecting shuang@10.28.0.34:3306

# %%
# import inspect
# inspect.getsourcelines(sk)

# %%
# sk_hyperpara.schema.drop()

# %%
sk_hyperpara.ModelSelection().populate(reserve_jobs=True)
# Out:
# Populating {'dataset_id': 1, 'random_start': 1, 'dataaug_id': 0, 'l1_id': 2, 'sm_lp_id': 0, 'l2_id': 2, 'lr_id': 1, 'seed': 0, 'iterations': 5, 'network_id': 1, 'sm_hm_id': 0}
# /src/Plasticity_Ker/PlasticityKer/modelval/data_aug_gp.py:223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   new_entry['dw_mean'] = sample
# /src/Plasticity_Ker/PlasticityKer/modelval/data_aug_gp.py:232: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   y_test = np.concatenate([y_test2, data4['dw_mean'].reshape(-1, 1)])
# /src/Plasticity_Ker/PlasticityKer/modelval/ArbDataGen.py:240: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   target_tmp = targets[(df['ptl_idx'] == ptl_list[i]).reshape(-1, 1)]
# Initial validation mse=819.27197
# Global Step 0150 and Step 0150: validation mse=610.64612
# Updated min validation loss!Saving model...
# Global Step 0200 and Step 0200: validation mse=548.40814
# Updated min validation loss!Saving model...
# Global Step 0250 and Step 0250: validation mse=481.88205
# Updated min validation loss!Saving model...
# Global Step 0300 and Step 0300: validation mse=420.48886
# Updated min validation loss!Saving model...
# Global Step 0350 and Step 0350: validation mse=371.33929
# Updated min validation loss!Saving model...
# Global Step 0400 and Step 0400: validation mse=338.22900
# Updated min validation loss!Saving model...
# Global Step 0450 and Step 0450: validation mse=320.04999
# Updated min validation loss!Saving model...
# Global Step 0500 and Step 0500: validation mse=314.78201
# Updated min validation loss!Saving model...
# Global Step 0550 and Step 0550: validation mse=320.76447
# Global Step 0600 and Step 0600: validation mse=335.87766
# Global Step 0650 and Step 0650: validation mse=356.72882
# Global Step 0700 and Step 0700: validation mse=379.80518
# Global Step 0750 and Step 0750: validation mse=402.21613
# Global Step 0800 and Step 0800: validation mse=422.38971
# Global Step 0850 and Step 0850: validation mse=439.87888
# Global Step 0900 and Step 0900: validation mse=454.82666
# Global Step 0950 and Step 0950: validation mse=467.63986
# Global Step 1000 and Step 1000: validation mse=478.68927
# Global Step 1050 and Step 1050: validation mse=488.30505
# Global Step 1100 and Step 1100: validation mse=496.74835
# Global Step 1150 and Step 1150: validation mse=504.25711
# Global Step 1200 and Step 1200: validation mse=510.94086
# Global Step 1250 and Step 1250: validation mse=517.02063
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 1300 and Step 0050: validation mse=315.51492
# Global Step 1350 and Step 0100: validation mse=317.36475
# Global Step 1400 and Step 0150: validation mse=320.32858
# Global Step 1450 and Step 0200: validation mse=324.35989
# Global Step 1500 and Step 0250: validation mse=329.37204
# Global Step 1550 and Step 0300: validation mse=335.25012
# Global Step 1600 and Step 0350: validation mse=341.87616
# Global Step 1650 and Step 0400: validation mse=349.11569
# Global Step 1700 and Step 0450: validation mse=356.84653
# Global Step 1750 and Step 0500: validation mse=364.89667
# Global Step 1800 and Step 0550: validation mse=373.13095
# Global Step 1850 and Step 0600: validation mse=381.42657
# Global Step 1900 and Step 0650: validation mse=389.65991
# Global Step 1950 and Step 0700: validation mse=397.75208
# Global Step 2000 and Step 0750: validation mse=405.62769
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 2050 and Step 0050: validation mse=314.87637
# Global Step 2100 and Step 0100: validation mse=315.06702
# Global Step 2150 and Step 0150: validation mse=315.37790
# Global Step 2200 and Step 0200: validation mse=315.81079
# Global Step 2250 and Step 0250: validation mse=316.37448
# Global Step 2300 and Step 0300: validation mse=317.06613
# Global Step 2350 and Step 0350: validation mse=317.88922
# Global Step 2400 and Step 0400: validation mse=318.84949
# Global Step 2450 and Step 0450: validation mse=319.94241
# Global Step 2500 and Step 0500: validation mse=321.16895
# Global Step 2550 and Step 0550: validation mse=322.53635
# Global Step 2600 and Step 0600: validation mse=324.03305
# Global Step 2650 and Step 0650: validation mse=325.66711
# Global Step 2700 and Step 0700: validation mse=327.42657
# Global Step 2750 and Step 0750: validation mse=329.31146
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 2800 and Step 0050: validation mse=314.80048
# Global Step 2850 and Step 0100: validation mse=314.81088
# Global Step 2900 and Step 0150: validation mse=314.83023
# Global Step 2950 and Step 0200: validation mse=314.85925
# Global Step 3000 and Step 0250: validation mse=314.89691
# Global Step 3050 and Step 0300: validation mse=314.94919
# Global Step 3100 and Step 0350: validation mse=315.01135
# Global Step 3150 and Step 0400: validation mse=315.08859
# Global Step 3200 and Step 0450: validation mse=315.17966
# Global Step 3250 and Step 0500: validation mse=315.28412
# Global Step 3300 and Step 0550: validation mse=315.40134
# Global Step 3350 and Step 0600: validation mse=315.53503
# Global Step 3400 and Step 0650: validation mse=315.68234
# Global Step 3450 and Step 0700: validation mse=315.84634
# Global Step 3500 and Step 0750: validation mse=316.02411
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 3550 and Step 0050: validation mse=314.78970
# Global Step 3600 and Step 0100: validation mse=314.78723
# Global Step 3650 and Step 0150: validation mse=314.78339
# Global Step 3700 and Step 0200: validation mse=314.77817
# Updated min validation loss!Saving model...
# Global Step 3750 and Step 0250: validation mse=314.77344
# Updated min validation loss!Saving model...
# Global Step 3800 and Step 0300: validation mse=314.76846
# Updated min validation loss!Saving model...
# Global Step 3850 and Step 0350: validation mse=314.76367
# Updated min validation loss!Saving model...
# Global Step 3900 and Step 0400: validation mse=314.76013
# Updated min validation loss!Saving model...
# Global Step 3950 and Step 0450: validation mse=314.75754
# Updated min validation loss!Saving model...
# Global Step 4000 and Step 0500: validation mse=314.75589
# Updated min validation loss!Saving model...
# Global Step 4050 and Step 0550: validation mse=314.75592
# Global Step 4100 and Step 0600: validation mse=314.75650
# Global Step 4150 and Step 0650: validation mse=314.75854
# Global Step 4200 and Step 0700: validation mse=314.76154
# Global Step 4250 and Step 0750: validation mse=314.76602
# Global Step 4300 and Step 0800: validation mse=314.77167
# Global Step 4350 and Step 0850: validation mse=314.77853
# Global Step 4400 and Step 0900: validation mse=314.78702
# Global Step 4450 and Step 0950: validation mse=314.79611
# Global Step 4500 and Step 1000: validation mse=314.80701
# Global Step 4550 and Step 1050: validation mse=314.81924
# Global Step 4600 and Step 1100: validation mse=314.83286
# Global Step 4650 and Step 1150: validation mse=314.84735
# Global Step 4700 and Step 1200: validation mse=314.86432
# Global Step 4750 and Step 1250: validation mse=314.88095
# Early Stopping!!!
# Restoring the best parameters...
#
# Initial validation mse=436.76685
# Global Step 0150 and Step 0150: validation mse=317.96683
# Updated min validation loss!Saving model...
# Global Step 0200 and Step 0200: validation mse=298.39136
# Updated min validation loss!Saving model...
# Global Step 0250 and Step 0250: validation mse=280.76242
# Updated min validation loss!Saving model...
# Global Step 0300 and Step 0300: validation mse=263.92096
# Updated min validation loss!Saving model...
# Global Step 0350 and Step 0350: validation mse=248.61295
# Updated min validation loss!Saving model...
# Global Step 0400 and Step 0400: validation mse=237.70642
# Updated min validation loss!Saving model...
# Global Step 0450 and Step 0450: validation mse=231.31401
# Updated min validation loss!Saving model...
# Global Step 0500 and Step 0500: validation mse=228.61429
# Updated min validation loss!Saving model...
# Global Step 0550 and Step 0550: validation mse=230.16858
# Global Step 0600 and Step 0600: validation mse=236.33893
# Global Step 0650 and Step 0650: validation mse=244.77295
# Global Step 0700 and Step 0700: validation mse=254.02492
# Global Step 0750 and Step 0750: validation mse=262.91193
# Global Step 0800 and Step 0800: validation mse=270.69147
# Global Step 0850 and Step 0850: validation mse=277.00766
# Global Step 0900 and Step 0900: validation mse=281.75772
# Global Step 0950 and Step 0950: validation mse=285.06827
# Global Step 1000 and Step 1000: validation mse=287.12674
# Global Step 1050 and Step 1050: validation mse=288.24695
# Global Step 1100 and Step 1100: validation mse=288.60211
# Global Step 1150 and Step 1150: validation mse=288.47247
# Global Step 1200 and Step 1200: validation mse=288.13184
# Global Step 1250 and Step 1250: validation mse=287.68588
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 1300 and Step 0050: validation mse=228.49467
# Updated min validation loss!Saving model...
# Global Step 1350 and Step 0100: validation mse=228.77954
# Global Step 1400 and Step 0150: validation mse=230.01425
# Global Step 1450 and Step 0200: validation mse=231.77934
# Global Step 1500 and Step 0250: validation mse=233.93419
# Global Step 1550 and Step 0300: validation mse=236.47305
# Global Step 1600 and Step 0350: validation mse=239.31374
# Global Step 1650 and Step 0400: validation mse=242.42664
# Global Step 1700 and Step 0450: validation mse=245.73709
# Global Step 1750 and Step 0500: validation mse=249.16612
# Global Step 1800 and Step 0550: validation mse=252.66611
# Global Step 1850 and Step 0600: validation mse=256.16415
# Global Step 1900 and Step 0650: validation mse=259.63211
# Global Step 1950 and Step 0700: validation mse=263.00104
# Global Step 2000 and Step 0750: validation mse=266.22733
# Global Step 2050 and Step 0800: validation mse=269.30243
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 2100 and Step 0050: validation mse=228.53487
# Global Step 2150 and Step 0100: validation mse=228.60721
# Global Step 2200 and Step 0150: validation mse=228.71721
# Global Step 2250 and Step 0200: validation mse=229.06726
# Global Step 2300 and Step 0250: validation mse=229.46368
# Global Step 2350 and Step 0300: validation mse=229.94904
# Global Step 2400 and Step 0350: validation mse=230.49396
# Global Step 2450 and Step 0400: validation mse=231.09869
# Global Step 2500 and Step 0450: validation mse=231.76520
# Global Step 2550 and Step 0500: validation mse=232.49593
# Global Step 2600 and Step 0550: validation mse=233.29124
# Global Step 2650 and Step 0600: validation mse=234.15363
# Global Step 2700 and Step 0650: validation mse=235.08492
# Global Step 2750 and Step 0700: validation mse=236.07550
# Global Step 2800 and Step 0750: validation mse=237.12395
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 2850 and Step 0050: validation mse=228.50299
# Global Step 2900 and Step 0100: validation mse=228.50641
# Global Step 2950 and Step 0150: validation mse=228.50751
# Global Step 3000 and Step 0200: validation mse=228.50752
# Global Step 3050 and Step 0250: validation mse=228.50645
# Global Step 3100 and Step 0300: validation mse=228.50537
# Global Step 3150 and Step 0350: validation mse=228.50497
# Global Step 3200 and Step 0400: validation mse=228.50592
# Global Step 3250 and Step 0450: validation mse=228.58784
# Global Step 3300 and Step 0500: validation mse=228.67482
# Global Step 3350 and Step 0550: validation mse=228.76642
# Global Step 3400 and Step 0600: validation mse=228.86311
# Global Step 3450 and Step 0650: validation mse=228.96980
# Global Step 3500 and Step 0700: validation mse=229.09444
# Global Step 3550 and Step 0750: validation mse=229.22887
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 3600 and Step 0050: validation mse=228.49762
# Global Step 3650 and Step 0100: validation mse=228.49652
# Global Step 3700 and Step 0150: validation mse=228.49275
# Updated min validation loss!Saving model...
# Global Step 3750 and Step 0200: validation mse=228.48639
# Updated min validation loss!Saving model...
# Global Step 3800 and Step 0250: validation mse=228.47758
# Updated min validation loss!Saving model...
# Global Step 3850 and Step 0300: validation mse=228.46629
# Updated min validation loss!Saving model...
# Global Step 3900 and Step 0350: validation mse=228.45274
# Updated min validation loss!Saving model...
# Global Step 3950 and Step 0400: validation mse=228.43680
# Updated min validation loss!Saving model...
# Global Step 4000 and Step 0450: validation mse=228.41867
# Updated min validation loss!Saving model...
# Global Step 4050 and Step 0500: validation mse=228.39853
# Updated min validation loss!Saving model...
# Global Step 4100 and Step 0550: validation mse=228.37610
# Updated min validation loss!Saving model...
# Global Step 4150 and Step 0600: validation mse=228.35193
# Updated min validation loss!Saving model...
# Global Step 4200 and Step 0650: validation mse=228.32555
# Updated min validation loss!Saving model...
# Global Step 4250 and Step 0700: validation mse=228.29779
# Updated min validation loss!Saving model...
# Global Step 4300 and Step 0750: validation mse=228.26794
# Updated min validation loss!Saving model...
# Global Step 4350 and Step 0800: validation mse=228.23694
# Updated min validation loss!Saving model...
# Global Step 4400 and Step 0850: validation mse=228.20435
# Updated min validation loss!Saving model...
# Global Step 4450 and Step 0900: validation mse=228.17012
# Updated min validation loss!Saving model...
# Global Step 4500 and Step 0950: validation mse=228.13474
# Updated min validation loss!Saving model...
# Global Step 4550 and Step 1000: validation mse=228.12448
# Updated min validation loss!Saving model...
# Global Step 4600 and Step 1050: validation mse=228.12428
# Updated min validation loss!Saving model...
# Global Step 4650 and Step 1100: validation mse=228.12361
# Updated min validation loss!Saving model...
# Global Step 4700 and Step 1150: validation mse=228.12300
# Updated min validation loss!Saving model...
# Global Step 4750 and Step 1200: validation mse=228.12285
# Updated min validation loss!Saving model...
# Global Step 4800 and Step 1250: validation mse=228.12178
# Updated min validation loss!Saving model...
# Global Step 4850 and Step 1300: validation mse=228.12155
# Updated min validation loss!Saving model...
# Global Step 4900 and Step 1350: validation mse=228.12097
# Updated min validation loss!Saving model...
# Global Step 4950 and Step 1400: validation mse=228.12123
# Global Step 5000 and Step 1450: validation mse=228.12158
# Global Step 5050 and Step 1500: validation mse=228.12463
# Global Step 5100 and Step 1550: validation mse=228.13139
# Global Step 5150 and Step 1600: validation mse=228.13968
# Global Step 5200 and Step 1650: validation mse=228.15007
# Global Step 5250 and Step 1700: validation mse=228.16251
# Global Step 5300 and Step 1750: validation mse=228.17543
# Global Step 5350 and Step 1800: validation mse=228.19000
# Global Step 5400 and Step 1850: validation mse=228.20592
# Global Step 5450 and Step 1900: validation mse=228.22351
# Global Step 5500 and Step 1950: validation mse=228.24271
# Global Step 5550 and Step 2000: validation mse=228.26274
# Global Step 5600 and Step 2050: validation mse=228.28513
# Global Step 5650 and Step 2100: validation mse=228.30977
# Early Stopping!!!
# Restoring the best parameters...
#
# Initial validation mse=747.40472
# Global Step 0150 and Step 0150: validation mse=556.86920
# Updated min validation loss!Saving model...
# Global Step 0200 and Step 0200: validation mse=513.30804
# Updated min validation loss!Saving model...
# Global Step 0250 and Step 0250: validation mse=467.49603
# Updated min validation loss!Saving model...
# Global Step 0300 and Step 0300: validation mse=428.30594
# Updated min validation loss!Saving model...
# Global Step 0350 and Step 0350: validation mse=402.58337
# Updated min validation loss!Saving model...
# Global Step 0400 and Step 0400: validation mse=392.00378
# Updated min validation loss!Saving model...
# Global Step 0450 and Step 0450: validation mse=393.60156
# Global Step 0500 and Step 0500: validation mse=403.33826
# Global Step 0550 and Step 0550: validation mse=421.13300
# Global Step 0600 and Step 0600: validation mse=449.83377
# Global Step 0650 and Step 0650: validation mse=490.42926
# Global Step 0700 and Step 0700: validation mse=534.14783
# Global Step 0750 and Step 0750: validation mse=566.26263
# Global Step 0800 and Step 0800: validation mse=581.56134
# Global Step 0850 and Step 0850: validation mse=586.14447
# Global Step 0900 and Step 0900: validation mse=585.86829
# Global Step 0950 and Step 0950: validation mse=583.68158
# Global Step 1000 and Step 1000: validation mse=580.53162
# Global Step 1050 and Step 1050: validation mse=576.88574
# Global Step 1100 and Step 1100: validation mse=573.13135
# Global Step 1150 and Step 1150: validation mse=569.16235
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 1200 and Step 0050: validation mse=391.57684
# Updated min validation loss!Saving model...
# Global Step 1250 and Step 0100: validation mse=392.36328
# Global Step 1300 and Step 0150: validation mse=394.20309
# Global Step 1350 and Step 0200: validation mse=396.82190
# Global Step 1400 and Step 0250: validation mse=400.27826
# Global Step 1450 and Step 0300: validation mse=404.77676
# Global Step 1500 and Step 0350: validation mse=410.44257
# Global Step 1550 and Step 0400: validation mse=417.44702
# Global Step 1600 and Step 0450: validation mse=425.90503
# Global Step 1650 and Step 0500: validation mse=435.93256
# Global Step 1700 and Step 0550: validation mse=447.48535
# Global Step 1750 and Step 0600: validation mse=460.58038
# Global Step 1800 and Step 0650: validation mse=474.73251
# Global Step 1850 and Step 0700: validation mse=489.36298
# Global Step 1900 and Step 0750: validation mse=504.14191
# Global Step 1950 and Step 0800: validation mse=518.50256
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 2000 and Step 0050: validation mse=391.73431
# Global Step 2050 and Step 0100: validation mse=392.04077
# Global Step 2100 and Step 0150: validation mse=392.48907
# Global Step 2150 and Step 0200: validation mse=393.07709
# Global Step 2200 and Step 0250: validation mse=393.80569
# Global Step 2250 and Step 0300: validation mse=394.66455
# Global Step 2300 and Step 0350: validation mse=395.59866
# Global Step 2350 and Step 0400: validation mse=396.58820
# Global Step 2400 and Step 0450: validation mse=397.69614
# Global Step 2450 and Step 0500: validation mse=398.94269
# Global Step 2500 and Step 0550: validation mse=400.32541
# Global Step 2550 and Step 0600: validation mse=401.85696
# Global Step 2600 and Step 0650: validation mse=403.53772
# Global Step 2650 and Step 0700: validation mse=405.37872
# Global Step 2700 and Step 0750: validation mse=407.37991
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 2750 and Step 0050: validation mse=391.61548
# Global Step 2800 and Step 0100: validation mse=391.67517
# Global Step 2850 and Step 0150: validation mse=391.75818
# Global Step 2900 and Step 0200: validation mse=391.86746
# Global Step 2950 and Step 0250: validation mse=392.00079
# Global Step 3000 and Step 0300: validation mse=392.15942
# Global Step 3050 and Step 0350: validation mse=392.34317
# Global Step 3100 and Step 0400: validation mse=392.55237
# Global Step 3150 and Step 0450: validation mse=392.78320
# Global Step 3200 and Step 0500: validation mse=393.03662
# Global Step 3250 and Step 0550: validation mse=393.31360
# Global Step 3300 and Step 0600: validation mse=393.61179
# Global Step 3350 and Step 0650: validation mse=393.92905
# Global Step 3400 and Step 0700: validation mse=394.26575
# Global Step 3450 and Step 0750: validation mse=394.62497
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 3500 and Step 0050: validation mse=391.58719
# Global Step 3550 and Step 0100: validation mse=391.60098
# Global Step 3600 and Step 0150: validation mse=391.61835
# Global Step 3650 and Step 0200: validation mse=391.64008
# Global Step 3700 and Step 0250: validation mse=391.66730
# Global Step 3750 and Step 0300: validation mse=391.69965
# Global Step 3800 and Step 0350: validation mse=391.73764
# Global Step 3850 and Step 0400: validation mse=391.78082
# Global Step 3900 and Step 0450: validation mse=391.83038
# Global Step 3950 and Step 0500: validation mse=391.88507
# Global Step 4000 and Step 0550: validation mse=391.94540
# Global Step 4050 and Step 0600: validation mse=392.01129
# Global Step 4100 and Step 0650: validation mse=392.08228
# Global Step 4150 and Step 0700: validation mse=392.15869
# Global Step 4200 and Step 0750: validation mse=392.24039
# Early Stopping!!!
# Restoring the best parameters...
#
# Initial validation mse=1806.79443
# Global Step 0150 and Step 0150: validation mse=1732.29639
# Updated min validation loss!Saving model...
# Global Step 0200 and Step 0200: validation mse=1705.53687
# Updated min validation loss!Saving model...
# Global Step 0250 and Step 0250: validation mse=1661.53259
# Updated min validation loss!Saving model...
# Global Step 0300 and Step 0300: validation mse=1598.23584
# Updated min validation loss!Saving model...
# Global Step 0350 and Step 0350: validation mse=1520.77478
# Updated min validation loss!Saving model...
# Global Step 0400 and Step 0400: validation mse=1438.64575
# Updated min validation loss!Saving model...
# Global Step 0450 and Step 0450: validation mse=1361.12695
# Updated min validation loss!Saving model...
# Global Step 0500 and Step 0500: validation mse=1293.79932
# Updated min validation loss!Saving model...
# Global Step 0550 and Step 0550: validation mse=1238.15430
# Updated min validation loss!Saving model...
# Global Step 0600 and Step 0600: validation mse=1193.59338
# Updated min validation loss!Saving model...
# Global Step 0650 and Step 0650: validation mse=1158.22534
# Updated min validation loss!Saving model...
# Global Step 0700 and Step 0700: validation mse=1130.80176
# Updated min validation loss!Saving model...
# Global Step 0750 and Step 0750: validation mse=1109.63147
# Updated min validation loss!Saving model...
# Global Step 0800 and Step 0800: validation mse=1093.33923
# Updated min validation loss!Saving model...
# Global Step 0850 and Step 0850: validation mse=1080.93250
# Updated min validation loss!Saving model...
# Global Step 0900 and Step 0900: validation mse=1071.07153
# Updated min validation loss!Saving model...
# Global Step 0950 and Step 0950: validation mse=1062.93481
# Updated min validation loss!Saving model...
# Global Step 1000 and Step 1000: validation mse=1055.99756
# Updated min validation loss!Saving model...
# Global Step 1050 and Step 1050: validation mse=1049.53174
# Updated min validation loss!Saving model...
# Global Step 1100 and Step 1100: validation mse=1043.31750
# Updated min validation loss!Saving model...
# Global Step 1150 and Step 1150: validation mse=1036.79810
# Updated min validation loss!Saving model...
# Global Step 1200 and Step 1200: validation mse=1030.07690
# Updated min validation loss!Saving model...
# Global Step 1250 and Step 1250: validation mse=1023.12610
# Updated min validation loss!Saving model...
# Global Step 1300 and Step 1300: validation mse=1015.71490
# Updated min validation loss!Saving model...
# Global Step 1350 and Step 1350: validation mse=1007.91528
# Updated min validation loss!Saving model...
# Global Step 1400 and Step 1400: validation mse=999.77563
# Updated min validation loss!Saving model...
# Global Step 1450 and Step 1450: validation mse=991.23193
# Updated min validation loss!Saving model...
# Global Step 1500 and Step 1500: validation mse=982.57251
# Updated min validation loss!Saving model...
# Global Step 1550 and Step 1550: validation mse=973.84570
# Updated min validation loss!Saving model...
# Global Step 1600 and Step 1600: validation mse=965.30756
# Updated min validation loss!Saving model...
# Global Step 1650 and Step 1650: validation mse=956.82874
# Updated min validation loss!Saving model...
# Global Step 1700 and Step 1700: validation mse=948.81342
# Updated min validation loss!Saving model...
# Global Step 1750 and Step 1750: validation mse=941.16388
# Updated min validation loss!Saving model...
# Global Step 1800 and Step 1800: validation mse=934.16528
# Updated min validation loss!Saving model...
# Global Step 1850 and Step 1850: validation mse=927.62598
# Updated min validation loss!Saving model...
# Global Step 1900 and Step 1900: validation mse=921.72852
# Updated min validation loss!Saving model...
# Global Step 1950 and Step 1950: validation mse=916.53534
# Updated min validation loss!Saving model...
# Global Step 2000 and Step 2000: validation mse=912.02661
# Updated min validation loss!Saving model...
# Global Step 2050 and Step 2050: validation mse=908.39532
# Updated min validation loss!Saving model...
# Global Step 2100 and Step 2100: validation mse=905.38757
# Updated min validation loss!Saving model...
# Global Step 2150 and Step 2150: validation mse=903.03375
# Updated min validation loss!Saving model...
# Global Step 2200 and Step 2200: validation mse=901.34351
# Updated min validation loss!Saving model...
# Global Step 2250 and Step 2250: validation mse=900.19635
# Updated min validation loss!Saving model...
# Global Step 2300 and Step 2300: validation mse=899.31879
# Updated min validation loss!Saving model...
# Global Step 2350 and Step 2350: validation mse=899.05414
# Updated min validation loss!Saving model...
# Global Step 2400 and Step 2400: validation mse=898.65448
# Updated min validation loss!Saving model...
# Global Step 2450 and Step 2450: validation mse=898.77808
# Global Step 2500 and Step 2500: validation mse=898.95178
# Global Step 2550 and Step 2550: validation mse=898.93878
# Global Step 2600 and Step 2600: validation mse=899.14954
# Global Step 2650 and Step 2650: validation mse=899.38647
# Global Step 2700 and Step 2700: validation mse=899.22095
# Global Step 2750 and Step 2750: validation mse=899.49933
# Global Step 2800 and Step 2800: validation mse=899.28564
# Global Step 2850 and Step 2850: validation mse=899.39386
# Global Step 2900 and Step 2900: validation mse=899.26624
# Global Step 2950 and Step 2950: validation mse=899.07550
# Global Step 3000 and Step 3000: validation mse=899.17566
# Global Step 3050 and Step 3050: validation mse=898.64001
# Updated min validation loss!Saving model...
# Global Step 3100 and Step 3100: validation mse=898.32666
# Updated min validation loss!Saving model...
# Global Step 3150 and Step 3150: validation mse=898.26007
# Updated min validation loss!Saving model...
# Global Step 3200 and Step 3200: validation mse=897.56195
# Updated min validation loss!Saving model...
# Global Step 3250 and Step 3250: validation mse=897.09888
# Updated min validation loss!Saving model...
# Global Step 3300 and Step 3300: validation mse=896.44873
# Updated min validation loss!Saving model...
# Global Step 3350 and Step 3350: validation mse=895.79443
# Updated min validation loss!Saving model...
# Global Step 3400 and Step 3400: validation mse=894.99341
# Updated min validation loss!Saving model...
# Global Step 3450 and Step 3450: validation mse=894.12537
# Updated min validation loss!Saving model...
# Global Step 3500 and Step 3500: validation mse=892.80048
# Updated min validation loss!Saving model...
# Global Step 3550 and Step 3550: validation mse=891.89636
# Updated min validation loss!Saving model...
# Global Step 3600 and Step 3600: validation mse=890.68274
# Updated min validation loss!Saving model...
# Global Step 3650 and Step 3650: validation mse=889.22003
# Updated min validation loss!Saving model...
# Global Step 3700 and Step 3700: validation mse=887.53076
# Updated min validation loss!Saving model...
# Global Step 3750 and Step 3750: validation mse=885.39490
# Updated min validation loss!Saving model...
# Global Step 3800 and Step 3800: validation mse=883.43408
# Updated min validation loss!Saving model...
# Global Step 3850 and Step 3850: validation mse=880.82568
# Updated min validation loss!Saving model...
# Global Step 3900 and Step 3900: validation mse=877.98352
# Updated min validation loss!Saving model...
# Global Step 3950 and Step 3950: validation mse=875.01086
# Updated min validation loss!Saving model...
# Global Step 4000 and Step 4000: validation mse=871.23181
# Updated min validation loss!Saving model...
# Global Step 4050 and Step 4050: validation mse=867.52710
# Updated min validation loss!Saving model...
# Global Step 4100 and Step 4100: validation mse=862.88843
# Updated min validation loss!Saving model...
# Global Step 4150 and Step 4150: validation mse=857.95636
# Updated min validation loss!Saving model...
# Global Step 4200 and Step 4200: validation mse=852.33972
# Updated min validation loss!Saving model...
# Global Step 4250 and Step 4250: validation mse=846.16974
# Updated min validation loss!Saving model...
# Global Step 4300 and Step 4300: validation mse=838.82062
# Updated min validation loss!Saving model...
# Global Step 4350 and Step 4350: validation mse=830.53876
# Updated min validation loss!Saving model...
# Global Step 4400 and Step 4400: validation mse=821.45361
# Updated min validation loss!Saving model...
# Global Step 4450 and Step 4450: validation mse=811.29993
# Updated min validation loss!Saving model...
# Global Step 4500 and Step 4500: validation mse=799.91541
# Updated min validation loss!Saving model...
# Global Step 4550 and Step 4550: validation mse=787.47314
# Updated min validation loss!Saving model...
# Global Step 4600 and Step 4600: validation mse=773.53723
# Updated min validation loss!Saving model...
# Global Step 4650 and Step 4650: validation mse=758.69958
# Updated min validation loss!Saving model...
# Global Step 4700 and Step 4700: validation mse=742.25525
# Updated min validation loss!Saving model...
# Global Step 4750 and Step 4750: validation mse=725.50769
# Updated min validation loss!Saving model...
# Global Step 4800 and Step 4800: validation mse=707.75732
# Updated min validation loss!Saving model...
# Global Step 4850 and Step 4850: validation mse=690.44800
# Updated min validation loss!Saving model...
# Global Step 4900 and Step 4900: validation mse=673.52423
# Updated min validation loss!Saving model...
# Global Step 4950 and Step 4950: validation mse=657.90717
# Updated min validation loss!Saving model...
# Global Step 5000 and Step 5000: validation mse=644.29456
# Updated min validation loss!Saving model...
# Global Step 5050 and Step 5050: validation mse=633.45709
# Updated min validation loss!Saving model...
# Global Step 5100 and Step 5100: validation mse=625.78369
# Updated min validation loss!Saving model...
# Global Step 5150 and Step 5150: validation mse=621.25305
# Updated min validation loss!Saving model...
# Global Step 5200 and Step 5200: validation mse=619.36987
# Updated min validation loss!Saving model...
# Global Step 5250 and Step 5250: validation mse=620.32434
# Global Step 5300 and Step 5300: validation mse=623.15173
# Global Step 5350 and Step 5350: validation mse=627.43982
# Global Step 5400 and Step 5400: validation mse=632.78735
# Global Step 5450 and Step 5450: validation mse=639.01025
# Global Step 5500 and Step 5500: validation mse=646.02728
# Global Step 5550 and Step 5550: validation mse=653.67920
# Global Step 5600 and Step 5600: validation mse=662.37115
# Global Step 5650 and Step 5650: validation mse=671.36743
# Global Step 5700 and Step 5700: validation mse=680.77740
# Global Step 5750 and Step 5750: validation mse=690.89410
# Global Step 5800 and Step 5800: validation mse=702.54498
# Global Step 5850 and Step 5850: validation mse=714.35083
# Global Step 5900 and Step 5900: validation mse=727.54791
# Global Step 5950 and Step 5950: validation mse=741.31543
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 6000 and Step 0050: validation mse=619.54553
# Global Step 6050 and Step 0100: validation mse=619.85004
# Global Step 6100 and Step 0150: validation mse=620.33398
# Global Step 6150 and Step 0200: validation mse=621.10773
# Global Step 6200 and Step 0250: validation mse=622.17163
# Global Step 6250 and Step 0300: validation mse=623.43567
# Global Step 6300 and Step 0350: validation mse=624.85608
# Global Step 6350 and Step 0400: validation mse=626.49915
# Global Step 6400 and Step 0450: validation mse=628.39478
# Global Step 6450 and Step 0500: validation mse=630.38940
# Global Step 6500 and Step 0550: validation mse=632.51056
# Global Step 6550 and Step 0600: validation mse=634.91217
# Global Step 6600 and Step 0650: validation mse=637.48358
# Global Step 6650 and Step 0700: validation mse=640.14142
# Global Step 6700 and Step 0750: validation mse=643.02527
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 6750 and Step 0050: validation mse=619.54535
# Global Step 6800 and Step 0100: validation mse=619.54047
# Global Step 6850 and Step 0150: validation mse=619.58459
# Global Step 6900 and Step 0200: validation mse=619.64526
# Global Step 6950 and Step 0250: validation mse=619.73657
# Global Step 7000 and Step 0300: validation mse=619.89160
# Global Step 7050 and Step 0350: validation mse=620.05243
# Global Step 7100 and Step 0400: validation mse=620.28479
# Global Step 7150 and Step 0450: validation mse=620.51459
# Global Step 7200 and Step 0500: validation mse=620.78870
# Global Step 7250 and Step 0550: validation mse=621.13080
# Global Step 7300 and Step 0600: validation mse=621.47809
# Global Step 7350 and Step 0650: validation mse=621.90710
# Global Step 7400 and Step 0700: validation mse=622.32410
# Global Step 7450 and Step 0750: validation mse=622.81152
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 7500 and Step 0050: validation mse=619.52991
# Global Step 7550 and Step 0100: validation mse=619.53973
# Global Step 7600 and Step 0150: validation mse=619.53314
# Global Step 7650 and Step 0200: validation mse=619.53198
# Global Step 7700 and Step 0250: validation mse=619.54028
# Global Step 7750 and Step 0300: validation mse=619.54346
# Global Step 7800 and Step 0350: validation mse=619.55920
# Global Step 7850 and Step 0400: validation mse=619.57422
# Global Step 7900 and Step 0450: validation mse=619.59106
# Global Step 7950 and Step 0500: validation mse=619.61823
# Global Step 8000 and Step 0550: validation mse=619.65039
# Global Step 8050 and Step 0600: validation mse=619.68170
# Global Step 8100 and Step 0650: validation mse=619.72644
# Global Step 8150 and Step 0700: validation mse=619.77277
# Global Step 8200 and Step 0750: validation mse=619.82538
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 8250 and Step 0050: validation mse=619.55670
# Global Step 8300 and Step 0100: validation mse=619.53625
# Global Step 8350 and Step 0150: validation mse=619.53662
# Global Step 8400 and Step 0200: validation mse=619.53516
# Global Step 8450 and Step 0250: validation mse=619.53497
# Global Step 8500 and Step 0300: validation mse=619.53046
# Global Step 8550 and Step 0350: validation mse=619.53180
# Global Step 8600 and Step 0400: validation mse=619.53381
# Global Step 8650 and Step 0450: validation mse=619.53247
# Global Step 8700 and Step 0500: validation mse=619.53186
# Global Step 8750 and Step 0550: validation mse=619.53296
# Global Step 8800 and Step 0600: validation mse=619.53546
# Global Step 8850 and Step 0650: validation mse=619.53809
# Global Step 8900 and Step 0700: validation mse=619.54138
# Global Step 8950 and Step 0750: validation mse=619.54358
# Early Stopping!!!
# Restoring the best parameters...
#
# Initial validation mse=379.05557
# Global Step 0150 and Step 0150: validation mse=305.54330
# Updated min validation loss!Saving model...
# Global Step 0200 and Step 0200: validation mse=297.31430
# Updated min validation loss!Saving model...
# Global Step 0250 and Step 0250: validation mse=282.58661
# Updated min validation loss!Saving model...
# Global Step 0300 and Step 0300: validation mse=259.30389
# Updated min validation loss!Saving model...
# Global Step 0350 and Step 0350: validation mse=231.74069
# Updated min validation loss!Saving model...
# Global Step 0400 and Step 0400: validation mse=210.05145
# Updated min validation loss!Saving model...
# Global Step 0450 and Step 0450: validation mse=198.85254
# Updated min validation loss!Saving model...
# Global Step 0500 and Step 0500: validation mse=197.52792
# Updated min validation loss!Saving model...
# Global Step 0550 and Step 0550: validation mse=202.81091
# Global Step 0600 and Step 0600: validation mse=211.18329
# Global Step 0650 and Step 0650: validation mse=219.84845
# Global Step 0700 and Step 0700: validation mse=227.19226
# Global Step 0750 and Step 0750: validation mse=232.56874
# Global Step 0800 and Step 0800: validation mse=236.05769
# Global Step 0850 and Step 0850: validation mse=238.10509
# Global Step 0900 and Step 0900: validation mse=239.22678
# Global Step 0950 and Step 0950: validation mse=239.83745
# Global Step 1000 and Step 1000: validation mse=240.22752
# Global Step 1050 and Step 1050: validation mse=240.55423
# Global Step 1100 and Step 1100: validation mse=240.91148
# Global Step 1150 and Step 1150: validation mse=241.34032
# Global Step 1200 and Step 1200: validation mse=241.85162
# Global Step 1250 and Step 1250: validation mse=242.44260
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 1300 and Step 0050: validation mse=198.73950
# Global Step 1350 and Step 0100: validation mse=200.52548
# Global Step 1400 and Step 0150: validation mse=202.78748
# Global Step 1450 and Step 0200: validation mse=205.41956
# Global Step 1500 and Step 0250: validation mse=208.30782
# Global Step 1550 and Step 0300: validation mse=211.34756
# Global Step 1600 and Step 0350: validation mse=214.44556
# Global Step 1650 and Step 0400: validation mse=217.52145
# Global Step 1700 and Step 0450: validation mse=220.49280
# Global Step 1750 and Step 0500: validation mse=223.30171
# Global Step 1800 and Step 0550: validation mse=225.89830
# Global Step 1850 and Step 0600: validation mse=228.24327
# Global Step 1900 and Step 0650: validation mse=230.31998
# Global Step 1950 and Step 0700: validation mse=232.11723
# Global Step 2000 and Step 0750: validation mse=233.64542
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 2050 and Step 0050: validation mse=197.86691
# Global Step 2100 and Step 0100: validation mse=198.27631
# Global Step 2150 and Step 0150: validation mse=198.75543
# Global Step 2200 and Step 0200: validation mse=199.30449
# Global Step 2250 and Step 0250: validation mse=199.92235
# Global Step 2300 and Step 0300: validation mse=200.60970
# Global Step 2350 and Step 0350: validation mse=201.36310
# Global Step 2400 and Step 0400: validation mse=202.17934
# Global Step 2450 and Step 0450: validation mse=203.05417
# Global Step 2500 and Step 0500: validation mse=203.98305
# Global Step 2550 and Step 0550: validation mse=204.96117
# Global Step 2600 and Step 0600: validation mse=205.98347
# Global Step 2650 and Step 0650: validation mse=207.04468
# Global Step 2700 and Step 0700: validation mse=208.13889
# Global Step 2750 and Step 0750: validation mse=209.26363
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 2800 and Step 0050: validation mse=197.63428
# Global Step 2850 and Step 0100: validation mse=197.74887
# Global Step 2900 and Step 0150: validation mse=197.86943
# Global Step 2950 and Step 0200: validation mse=197.99551
# Global Step 3000 and Step 0250: validation mse=198.12740
# Global Step 3050 and Step 0300: validation mse=198.26622
# Global Step 3100 and Step 0350: validation mse=198.41208
# Global Step 3150 and Step 0400: validation mse=198.56635
# Global Step 3200 and Step 0450: validation mse=198.72925
# Global Step 3250 and Step 0500: validation mse=198.90187
# Global Step 3300 and Step 0550: validation mse=199.08453
# Global Step 3350 and Step 0600: validation mse=199.27744
# Global Step 3400 and Step 0650: validation mse=199.48166
# Global Step 3450 and Step 0700: validation mse=199.69690
# Global Step 3500 and Step 0750: validation mse=199.92365
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 3550 and Step 0050: validation mse=197.56296
# Global Step 3600 and Step 0100: validation mse=197.59882
# Global Step 3650 and Step 0150: validation mse=197.63477
# Global Step 3700 and Step 0200: validation mse=197.67007
# Global Step 3750 and Step 0250: validation mse=197.70427
# Global Step 3800 and Step 0300: validation mse=197.73752
# Global Step 3850 and Step 0350: validation mse=197.76953
# Global Step 3900 and Step 0400: validation mse=197.80038
# Global Step 3950 and Step 0450: validation mse=197.83032
# Global Step 4000 and Step 0500: validation mse=197.85910
# Global Step 4050 and Step 0550: validation mse=197.88734
# Global Step 4100 and Step 0600: validation mse=197.91498
# Global Step 4150 and Step 0650: validation mse=197.94249
# Global Step 4200 and Step 0700: validation mse=197.96994
# Global Step 4250 and Step 0750: validation mse=197.99706
# Early Stopping!!!
# Restoring the best parameters...
# Populating {'dataset_id': 1, 'random_start': 1, 'dataaug_id': 1, 'l1_id': 2, 'sm_lp_id': 0, 'l2_id': 2, 'lr_id': 1, 'seed': 100, 'iterations': 5, 'network_id': 1, 'sm_hm_id': 0}
# /src/Plasticity_Ker/PlasticityKer/modelval/gp_regressor.py:132: RuntimeWarning: covariance is not positive-semidefinite.
#   y_test.append(np.random.multivariate_normal(np.squeeze(self.f), self.v_f, 1))
# /src/Plasticity_Ker/PlasticityKer/modelval/data_aug_gp.py:223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   new_entry['dw_mean'] = sample
# /src/Plasticity_Ker/PlasticityKer/modelval/data_aug_gp.py:232: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   y_test = np.concatenate([y_test2, data4['dw_mean'].reshape(-1, 1)])
# /src/Plasticity_Ker/PlasticityKer/modelval/data_aug_gp.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   new_try1['dt1'] = dt[i]
# /src/Plasticity_Ker/PlasticityKer/modelval/data_aug_gp.py:155: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   new_try3['dt2'] = dt[i]
# /src/Plasticity_Ker/PlasticityKer/modelval/ArbDataGen.py:240: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   target_tmp = targets[(df['ptl_idx'] == ptl_list[i]).reshape(-1, 1)]
# Initial validation mse=205.03920
# Global Step 0150 and Step 0150: validation mse=124.20231
# Updated min validation loss!Saving model...
# Global Step 0200 and Step 0200: validation mse=115.70230
# Updated min validation loss!Saving model...
# Global Step 0250 and Step 0250: validation mse=107.97987
# Updated min validation loss!Saving model...
# Global Step 0300 and Step 0300: validation mse=99.97475
# Updated min validation loss!Saving model...
# Global Step 0350 and Step 0350: validation mse=91.27092
# Updated min validation loss!Saving model...
# Global Step 0400 and Step 0400: validation mse=82.00541
# Updated min validation loss!Saving model...
# Global Step 0450 and Step 0450: validation mse=73.00701
# Updated min validation loss!Saving model...
# Global Step 0500 and Step 0500: validation mse=64.93660
# Updated min validation loss!Saving model...
# Global Step 0550 and Step 0550: validation mse=58.11832
# Updated min validation loss!Saving model...
# Global Step 0600 and Step 0600: validation mse=52.67750
# Updated min validation loss!Saving model...
# Global Step 0650 and Step 0650: validation mse=48.70773
# Updated min validation loss!Saving model...
# Global Step 0700 and Step 0700: validation mse=45.73793
# Updated min validation loss!Saving model...
# Global Step 0750 and Step 0750: validation mse=43.56399
# Updated min validation loss!Saving model...
# Global Step 0800 and Step 0800: validation mse=41.95972
# Updated min validation loss!Saving model...
# Global Step 0850 and Step 0850: validation mse=40.75235
# Updated min validation loss!Saving model...
# Global Step 0900 and Step 0900: validation mse=39.62159
# Updated min validation loss!Saving model...
# Global Step 0950 and Step 0950: validation mse=38.80958
# Updated min validation loss!Saving model...
# Global Step 1000 and Step 1000: validation mse=38.12884
# Updated min validation loss!Saving model...
# Global Step 1050 and Step 1050: validation mse=37.58807
# Updated min validation loss!Saving model...
# Global Step 1100 and Step 1100: validation mse=37.10106
# Updated min validation loss!Saving model...
# Global Step 1150 and Step 1150: validation mse=36.67617
# Updated min validation loss!Saving model...
# Global Step 1200 and Step 1200: validation mse=36.32066
# Updated min validation loss!Saving model...
# Global Step 1250 and Step 1250: validation mse=35.99717
# Updated min validation loss!Saving model...
# Global Step 1300 and Step 1300: validation mse=35.72684
# Updated min validation loss!Saving model...
# Global Step 1350 and Step 1350: validation mse=35.69958
# Updated min validation loss!Saving model...
# Global Step 1400 and Step 1400: validation mse=35.55466
# Updated min validation loss!Saving model...
# Global Step 1450 and Step 1450: validation mse=35.31042
# Updated min validation loss!Saving model...
# Global Step 1500 and Step 1500: validation mse=35.14352
# Updated min validation loss!Saving model...
# Global Step 1550 and Step 1550: validation mse=34.98774
# Updated min validation loss!Saving model...
# Global Step 1600 and Step 1600: validation mse=34.88947
# Updated min validation loss!Saving model...
# Global Step 1650 and Step 1650: validation mse=34.75538
# Updated min validation loss!Saving model...
# Global Step 1700 and Step 1700: validation mse=34.62009
# Updated min validation loss!Saving model...
# Global Step 1750 and Step 1750: validation mse=34.53098
# Updated min validation loss!Saving model...
# Global Step 1800 and Step 1800: validation mse=34.53397
# Global Step 1850 and Step 1850: validation mse=34.36425
# Updated min validation loss!Saving model...
# Global Step 1900 and Step 1900: validation mse=34.42593
# Global Step 1950 and Step 1950: validation mse=34.09203
# Updated min validation loss!Saving model...
# Global Step 2000 and Step 2000: validation mse=34.08237
# Updated min validation loss!Saving model...
# Global Step 2050 and Step 2050: validation mse=33.81906
# Updated min validation loss!Saving model...
# Global Step 2100 and Step 2100: validation mse=33.72046
# Updated min validation loss!Saving model...
# Global Step 2150 and Step 2150: validation mse=33.61223
# Updated min validation loss!Saving model...
# Global Step 2200 and Step 2200: validation mse=33.65027
# Global Step 2250 and Step 2250: validation mse=33.53374
# Updated min validation loss!Saving model...
# Global Step 2300 and Step 2300: validation mse=33.35705
# Updated min validation loss!Saving model...
# Global Step 2350 and Step 2350: validation mse=33.32529
# Updated min validation loss!Saving model...
# Global Step 2400 and Step 2400: validation mse=33.25480
# Updated min validation loss!Saving model...
# Global Step 2450 and Step 2450: validation mse=32.95855
# Updated min validation loss!Saving model...
# Global Step 2500 and Step 2500: validation mse=32.91858
# Updated min validation loss!Saving model...
# Global Step 2550 and Step 2550: validation mse=32.68407
# Updated min validation loss!Saving model...
# Global Step 2600 and Step 2600: validation mse=32.43034
# Updated min validation loss!Saving model...
# Global Step 2650 and Step 2650: validation mse=32.41306
# Updated min validation loss!Saving model...
# Global Step 2700 and Step 2700: validation mse=32.07224
# Updated min validation loss!Saving model...
# Global Step 2750 and Step 2750: validation mse=31.97893
# Updated min validation loss!Saving model...
# Global Step 2800 and Step 2800: validation mse=31.80954
# Updated min validation loss!Saving model...
# Global Step 2850 and Step 2850: validation mse=31.72203
# Updated min validation loss!Saving model...
# Global Step 2900 and Step 2900: validation mse=31.69412
# Updated min validation loss!Saving model...
# Global Step 2950 and Step 2950: validation mse=31.47637
# Updated min validation loss!Saving model...
# Global Step 3000 and Step 3000: validation mse=31.32504
# Updated min validation loss!Saving model...
# ...
# Updated min validation loss!Saving model...
# Global Step 1400 and Step 1400: validation mse=38.06355
# Updated min validation loss!Saving model...
# Global Step 1450 and Step 1450: validation mse=37.33030
# Updated min validation loss!Saving model...
# Global Step 1500 and Step 1500: validation mse=36.76064
# Updated min validation loss!Saving model...
# Global Step 1550 and Step 1550: validation mse=36.38023
# Updated min validation loss!Saving model...
# Global Step 1600 and Step 1600: validation mse=36.07973
# Updated min validation loss!Saving model...
# Global Step 1650 and Step 1650: validation mse=35.83998
# Updated min validation loss!Saving model...
# Global Step 1700 and Step 1700: validation mse=35.68447
# Updated min validation loss!Saving model...
# Global Step 1750 and Step 1750: validation mse=35.49167
# Updated min validation loss!Saving model...
# Global Step 1800 and Step 1800: validation mse=35.32256
# Updated min validation loss!Saving model...
# Global Step 1850 and Step 1850: validation mse=35.19060
# Updated min validation loss!Saving model...
# Global Step 1900 and Step 1900: validation mse=35.11280
# Updated min validation loss!Saving model...
# Global Step 1950 and Step 1950: validation mse=35.00128
# Updated min validation loss!Saving model...
# Global Step 2000 and Step 2000: validation mse=34.83925
# Updated min validation loss!Saving model...
# Global Step 2050 and Step 2050: validation mse=34.75238
# Updated min validation loss!Saving model...
# Global Step 2100 and Step 2100: validation mse=34.71175
# Updated min validation loss!Saving model...
# Global Step 2150 and Step 2150: validation mse=34.65696
# Updated min validation loss!Saving model...
# Global Step 2200 and Step 2200: validation mse=34.70053
# Global Step 2250 and Step 2250: validation mse=34.59707
# Updated min validation loss!Saving model...
# Global Step 2300 and Step 2300: validation mse=34.62562
# Global Step 2350 and Step 2350: validation mse=34.60740
# Global Step 2400 and Step 2400: validation mse=34.60523
# Global Step 2450 and Step 2450: validation mse=34.59106
# Updated min validation loss!Saving model...
# Global Step 2500 and Step 2500: validation mse=34.60559
# Global Step 2550 and Step 2550: validation mse=34.53829
# Updated min validation loss!Saving model...
# Global Step 2600 and Step 2600: validation mse=34.49061
# Updated min validation loss!Saving model...
# Global Step 2650 and Step 2650: validation mse=34.39672
# Updated min validation loss!Saving model...
# Global Step 2700 and Step 2700: validation mse=34.38315
# Updated min validation loss!Saving model...
# Global Step 2750 and Step 2750: validation mse=34.30769
# Updated min validation loss!Saving model...
# Global Step 2800 and Step 2800: validation mse=34.14893
# Updated min validation loss!Saving model...
# Global Step 2850 and Step 2850: validation mse=34.05552
# Updated min validation loss!Saving model...
# Global Step 2900 and Step 2900: validation mse=33.98802
# Updated min validation loss!Saving model...
# Global Step 2950 and Step 2950: validation mse=33.80798
# Updated min validation loss!Saving model...
# Global Step 3000 and Step 3000: validation mse=33.73426
# Updated min validation loss!Saving model...
# Global Step 3050 and Step 3050: validation mse=33.55570
# Updated min validation loss!Saving model...
# Global Step 3100 and Step 3100: validation mse=33.40017
# Updated min validation loss!Saving model...
# Global Step 3150 and Step 3150: validation mse=33.24566
# Updated min validation loss!Saving model...
# Global Step 3200 and Step 3200: validation mse=33.10110
# Updated min validation loss!Saving model...
# Global Step 3250 and Step 3250: validation mse=32.92163
# Updated min validation loss!Saving model...
# Global Step 3300 and Step 3300: validation mse=32.71585
# Updated min validation loss!Saving model...
# Global Step 3350 and Step 3350: validation mse=32.50095
# Updated min validation loss!Saving model...
# Global Step 3400 and Step 3400: validation mse=32.35010
# Updated min validation loss!Saving model...
# Global Step 3450 and Step 3450: validation mse=32.20775
# Updated min validation loss!Saving model...
# Global Step 3500 and Step 3500: validation mse=31.94437
# Updated min validation loss!Saving model...
# Global Step 3550 and Step 3550: validation mse=31.71599
# Updated min validation loss!Saving model...
# Global Step 3600 and Step 3600: validation mse=31.51510
# Updated min validation loss!Saving model...
# Global Step 3650 and Step 3650: validation mse=31.31734
# Updated min validation loss!Saving model...
# Global Step 3700 and Step 3700: validation mse=31.15129
# Updated min validation loss!Saving model...
# Global Step 3750 and Step 3750: validation mse=30.90970
# Updated min validation loss!Saving model...
# Global Step 3800 and Step 3800: validation mse=30.68459
# Updated min validation loss!Saving model...
# Global Step 3850 and Step 3850: validation mse=30.55606
# Updated min validation loss!Saving model...
# Global Step 3900 and Step 3900: validation mse=30.36449
# Updated min validation loss!Saving model...
# Global Step 3950 and Step 3950: validation mse=30.10858
# Updated min validation loss!Saving model...
# Global Step 4000 and Step 4000: validation mse=29.97759
# Updated min validation loss!Saving model...
# Global Step 4050 and Step 4050: validation mse=29.80905
# Updated min validation loss!Saving model...
# Global Step 4100 and Step 4100: validation mse=29.61977
# Updated min validation loss!Saving model...
# Global Step 4150 and Step 4150: validation mse=29.46234
# Updated min validation loss!Saving model...
# Global Step 4200 and Step 4200: validation mse=29.20419
# Updated min validation loss!Saving model...
# Global Step 4250 and Step 4250: validation mse=29.08215
# Updated min validation loss!Saving model...
# Global Step 4300 and Step 4300: validation mse=28.88899
# Updated min validation loss!Saving model...
# Global Step 4350 and Step 4350: validation mse=28.73492
# Updated min validation loss!Saving model...
# Global Step 4400 and Step 4400: validation mse=28.54028
# Updated min validation loss!Saving model...
# Global Step 4450 and Step 4450: validation mse=28.46475
# Updated min validation loss!Saving model...
# Global Step 4500 and Step 4500: validation mse=28.23900
# Updated min validation loss!Saving model...
# Global Step 4550 and Step 4550: validation mse=28.11642
# Updated min validation loss!Saving model...
# Global Step 4600 and Step 4600: validation mse=27.95500
# Updated min validation loss!Saving model...
# Global Step 4650 and Step 4650: validation mse=27.83325
# Updated min validation loss!Saving model...
# Global Step 4700 and Step 4700: validation mse=27.66712
# Updated min validation loss!Saving model...
# Global Step 4750 and Step 4750: validation mse=27.57173
# Updated min validation loss!Saving model...
# Global Step 4800 and Step 4800: validation mse=27.41737
# Updated min validation loss!Saving model...
# Global Step 4850 and Step 4850: validation mse=27.23318
# Updated min validation loss!Saving model...
# Global Step 4900 and Step 4900: validation mse=27.12966
# Updated min validation loss!Saving model...
# Global Step 4950 and Step 4950: validation mse=26.99982
# Updated min validation loss!Saving model...
# Global Step 5000 and Step 5000: validation mse=26.85001
# Updated min validation loss!Saving model...
# Global Step 5050 and Step 5050: validation mse=26.63390
# Updated min validation loss!Saving model...
# Global Step 5100 and Step 5100: validation mse=26.66521
# Global Step 5150 and Step 5150: validation mse=26.54140
# Updated min validation loss!Saving model...
# Global Step 5200 and Step 5200: validation mse=26.43043
# Updated min validation loss!Saving model...
# Global Step 5250 and Step 5250: validation mse=26.22960
# Updated min validation loss!Saving model...
# Global Step 5300 and Step 5300: validation mse=26.20813
# Updated min validation loss!Saving model...
# Global Step 5350 and Step 5350: validation mse=25.98850
# Updated min validation loss!Saving model...
# Global Step 5400 and Step 5400: validation mse=25.95210
# Updated min validation loss!Saving model...
# Global Step 5450 and Step 5450: validation mse=25.85966
# Updated min validation loss!Saving model...
# Global Step 5500 and Step 5500: validation mse=25.77351
# Updated min validation loss!Saving model...
# Global Step 5550 and Step 5550: validation mse=25.69250
# Updated min validation loss!Saving model...
# Global Step 5600 and Step 5600: validation mse=25.59677
# Updated min validation loss!Saving model...
# Global Step 5650 and Step 5650: validation mse=25.48011
# Updated min validation loss!Saving model...
# Global Step 5700 and Step 5700: validation mse=25.40898
# Updated min validation loss!Saving model...
# Global Step 5750 and Step 5750: validation mse=25.29728
# Updated min validation loss!Saving model...
# Global Step 5800 and Step 5800: validation mse=25.18114
# Updated min validation loss!Saving model...
# Global Step 5850 and Step 5850: validation mse=25.11126
# Updated min validation loss!Saving model...
# Global Step 5900 and Step 5900: validation mse=25.03214
# Updated min validation loss!Saving model...
# Global Step 5950 and Step 5950: validation mse=24.87181
# Updated min validation loss!Saving model...
# Global Step 6000 and Step 6000: validation mse=24.86687
# Updated min validation loss!Saving model...
# Global Step 6050 and Step 6050: validation mse=24.81211
# Updated min validation loss!Saving model...
# Global Step 6100 and Step 6100: validation mse=24.63367
# Updated min validation loss!Saving model...
# Global Step 6150 and Step 6150: validation mse=24.58766
# Updated min validation loss!Saving model...
# Global Step 6200 and Step 6200: validation mse=24.60923
# Global Step 6250 and Step 6250: validation mse=24.51723
# Updated min validation loss!Saving model...
# Global Step 6300 and Step 6300: validation mse=24.34913
# Updated min validation loss!Saving model...
# Global Step 6350 and Step 6350: validation mse=24.34553
# Updated min validation loss!Saving model...
# Global Step 6400 and Step 6400: validation mse=24.25711
# Updated min validation loss!Saving model...
# Global Step 6450 and Step 6450: validation mse=24.24511
# Updated min validation loss!Saving model...
# Global Step 6500 and Step 6500: validation mse=24.19572
# Updated min validation loss!Saving model...
# Global Step 6550 and Step 6550: validation mse=24.04309
# Updated min validation loss!Saving model...
# Global Step 6600 and Step 6600: validation mse=24.13457
# Global Step 6650 and Step 6650: validation mse=23.95774
# Updated min validation loss!Saving model...
# Global Step 6700 and Step 6700: validation mse=23.97504
# Global Step 6750 and Step 6750: validation mse=23.86968
# Updated min validation loss!Saving model...
# Global Step 6800 and Step 6800: validation mse=23.88136
# Global Step 6850 and Step 6850: validation mse=23.78780
# Updated min validation loss!Saving model...
# Global Step 6900 and Step 6900: validation mse=23.76730
# Updated min validation loss!Saving model...
# Global Step 6950 and Step 6950: validation mse=23.73028
# Updated min validation loss!Saving model...
# Global Step 7000 and Step 7000: validation mse=23.64758
# Updated min validation loss!Saving model...
# Global Step 7050 and Step 7050: validation mse=23.56987
# Updated min validation loss!Saving model...
# Global Step 7100 and Step 7100: validation mse=23.63415
# Global Step 7150 and Step 7150: validation mse=23.53181
# Updated min validation loss!Saving model...
# Global Step 7200 and Step 7200: validation mse=23.58648
# Global Step 7250 and Step 7250: validation mse=23.52456
# Updated min validation loss!Saving model...
# Global Step 7300 and Step 7300: validation mse=23.51976
# Updated min validation loss!Saving model...
# Global Step 7350 and Step 7350: validation mse=23.50156
# Updated min validation loss!Saving model...
# Global Step 7400 and Step 7400: validation mse=23.58446
# Global Step 7450 and Step 7450: validation mse=23.57647
# Global Step 7500 and Step 7500: validation mse=23.71733
# Global Step 7550 and Step 7550: validation mse=23.90510
# Global Step 7600 and Step 7600: validation mse=24.07033
# Global Step 7650 and Step 7650: validation mse=24.27538
# Global Step 7700 and Step 7700: validation mse=24.50836
# Global Step 7750 and Step 7750: validation mse=24.82502
# Global Step 7800 and Step 7800: validation mse=25.12315
# Global Step 7850 and Step 7850: validation mse=25.57919
# Global Step 7900 and Step 7900: validation mse=25.89413
# Global Step 7950 and Step 7950: validation mse=26.38351
# Global Step 8000 and Step 8000: validation mse=26.76406
# Global Step 8050 and Step 8050: validation mse=27.14643
# Global Step 8100 and Step 8100: validation mse=27.51141
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 8150 and Step 0050: validation mse=23.53083
# Global Step 8200 and Step 0100: validation mse=23.57714
# Global Step 8250 and Step 0150: validation mse=23.57844
# Global Step 8300 and Step 0200: validation mse=23.60174
# Global Step 8350 and Step 0250: validation mse=23.64476
# Global Step 8400 and Step 0300: validation mse=23.68405
# Global Step 8450 and Step 0350: validation mse=23.71844
# Global Step 8500 and Step 0400: validation mse=23.78840
# Global Step 8550 and Step 0450: validation mse=23.78320
# Global Step 8600 and Step 0500: validation mse=23.82741
# Global Step 8650 and Step 0550: validation mse=23.89729
# Global Step 8700 and Step 0600: validation mse=23.90830
# Global Step 8750 and Step 0650: validation mse=23.92667
# Global Step 8800 and Step 0700: validation mse=23.98833
# Global Step 8850 and Step 0750: validation mse=24.10003
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 8900 and Step 0050: validation mse=23.54092
# Global Step 8950 and Step 0100: validation mse=23.55668
# Global Step 9000 and Step 0150: validation mse=23.56472
# Global Step 9050 and Step 0200: validation mse=23.55972
# Global Step 9100 and Step 0250: validation mse=23.57236
# Global Step 9150 and Step 0300: validation mse=23.57456
# Global Step 9200 and Step 0350: validation mse=23.55909
# Global Step 9250 and Step 0400: validation mse=23.58084
# Global Step 9300 and Step 0450: validation mse=23.56356
# Global Step 9350 and Step 0500: validation mse=23.58092
# Global Step 9400 and Step 0550: validation mse=23.59011
# Global Step 9450 and Step 0600: validation mse=23.63928
# Global Step 9500 and Step 0650: validation mse=23.65275
# Global Step 9550 and Step 0700: validation mse=23.64165
# Global Step 9600 and Step 0750: validation mse=23.65961
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 9650 and Step 0050: validation mse=23.51184
# Global Step 9700 and Step 0100: validation mse=23.51533
# Global Step 9750 and Step 0150: validation mse=23.52577
# Global Step 9800 and Step 0200: validation mse=23.53488
# Global Step 9850 and Step 0250: validation mse=23.53839
# Global Step 9900 and Step 0300: validation mse=23.55422
# Global Step 9950 and Step 0350: validation mse=23.55343
# Global Step 10000 and Step 0400: validation mse=23.55545
# Global Step 10050 and Step 0450: validation mse=23.55246
# Global Step 10100 and Step 0500: validation mse=23.55777
# Global Step 10150 and Step 0550: validation mse=23.55512
# Global Step 10200 and Step 0600: validation mse=23.55507
# Global Step 10250 and Step 0650: validation mse=23.55610
# Global Step 10300 and Step 0700: validation mse=23.55839
# Global Step 10350 and Step 0750: validation mse=23.55499
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 10400 and Step 0050: validation mse=23.50662
# Global Step 10450 and Step 0100: validation mse=23.50950
# Global Step 10500 and Step 0150: validation mse=23.51038
# Global Step 10550 and Step 0200: validation mse=23.51600
# Global Step 10600 and Step 0250: validation mse=23.51951
# Global Step 10650 and Step 0300: validation mse=23.51649
# Global Step 10700 and Step 0350: validation mse=23.52155
# Global Step 10750 and Step 0400: validation mse=23.52100
# Global Step 10800 and Step 0450: validation mse=23.52169
# Global Step 10850 and Step 0500: validation mse=23.52327
# Global Step 10900 and Step 0550: validation mse=23.52572
# Global Step 10950 and Step 0600: validation mse=23.52596
# Global Step 11000 and Step 0650: validation mse=23.52881
# Global Step 11050 and Step 0700: validation mse=23.52781
# Global Step 11100 and Step 0750: validation mse=23.52629
# Early Stopping!!!
# Restoring the best parameters...

# %%
sk_hyperpara.ModelSelection().populate

# %%
sk_hyperpara.ModelSelection().populate(sk_hyperpara.Network() & 'somethign < 2', 'asdlhnkasdh')

# %%
sk_hyperpara.ModelSelection().progress()
# Out:
# ModelSelection       Completed 384 of 384 (100.0%)   2018-05-25 17:12:04
# (0, 384)

# %%
df = sk_hyperpara.ModelSelection() & ('l1_id=0')

# %%
df
# Out:
# *network_id    *dataset_id    *dataaug_id    *l1_id    *l2_id    *sm_lp_id    *sm_hm_id    *iterations    *lr_id    *random_start  *seed    pre_kernel post_kerne post_post_ val_error  bias       scale      fc_w
# +------------+ +------------+ +------------+ +-------+ +-------+ +----------+ +----------+ +------------+ +-------+ +------------+ +------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+
# 1              1              0              0         0         0            0            5              1         1              0        =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# 1              1              0              0         0         0            0            5              1         1              100      =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# 1              1              0              0         0         0            2            5              1         1              0        =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# 1              1              0              0         0         0            2            5              1         1              100      =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# 1              1              0              0         0         0            3            5              1         1              0        =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# 1              1              0              0         0         0            3            5              1         1              100      =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# 1              1              1              0         0         0            0            5              1         1              0        =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
#    ...
#  (18 tuples)

# %%
sk_hyperpara.ModelSelection()
# Out:
# *network_id    *dataset_id    *dataaug_id    *l1_id    *l2_id    *sm_lp_id    *sm_hm_id    *iterations    *lr_id    *random_start  *seed    pre_kernel post_kerne post_post_ val_error  bias       scale      fc_w
# +------------+ +------------+ +------------+ +-------+ +-------+ +----------+ +----------+ +------------+ +-------+ +------------+ +------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+ +--------+
# 1              1              0              0         0         0            0            5              1         1              0        =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# 1              1              0              0         0         0            0            5              1         1              100      =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# 1              1              0              0         0         0            2            5              1         1              0        =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# 1              1              0              0         0         0            2            5              1         1              100      =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# 1              1              0              0         0         0            3            5              1         1              0        =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# 1              1              0              0         0         0            3            5              1         1              100      =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
# 1              1              0              1         0         0            1            5              1         1              0        =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=     =BLOB=
#    ...
#  (69 tuples)

# %%
df= sk_hyperpara.ModelSelection()&('network_id=1')&('dataset_id=1')
ker_pre = np.squeeze(df.fetch('pre_kernel')[0])
ker_pre.transpose().shape
# Out:
# (101, 5)

# %%
df = sk.ModelSelection()&('network_id=1')&('dataset_id=2')
pre_ker= df.fetch['pre_kernel']
post_ker= df.fetch['post_kernel']
post_post_ker= df.fetch['post_post_kernel']

# %%
plt.plot(np.abs(pre_ker[0]),  label='ker_pre_trained')
plt.plot(np.abs(post_ker[0]),  label='ker_post_trained')
plt.plot(np.abs(post_post_ker[0]), label='ker_post_post_trained')
plt.legend()
