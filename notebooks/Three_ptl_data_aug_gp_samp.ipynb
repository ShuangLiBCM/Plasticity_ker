# %% [markdown]
# Augment the literature data

# %%
# Load libraries and modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from modelval import pairptl, network, trainer, dataset, data_aug_knn, perform_eval
from modelval.ArbDataGen import arb_w_gen
from modelval.spk_visu import spk_see, raster
from modelval import gp_regressor
from modelval import data_aug_gp
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

% matplotlib inline
% load_ext autoreload
% autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Load data frame
data = pd.read_csv('/src/Plasticity_Ker/data/kernel_training_data_auto.csv')
data.head()
# Out:
#    ptl_idx  pre_spk_num  pre_spk_freq  post_spk_num  post_spk_freq  ptl_occ  \
# 0        1            1             0             1              0       60
# 1        1            1             0             1              0       60
# 2        1            1             0             1              0       60
# 3        1            1             0             1              0       60
# 4        1            1             0             1              0       60
#
#    ptl_freq         dt1  dt2  dt3    dw_mean  dw_ste  train_len
# 0       1.0 -102.898046  0.0    0  -1.322590     0.0         60
# 1       1.0  -75.579896  0.0    0   2.674768     0.0         60
# 2       1.0  -80.871473  0.0    0 -12.696449     0.0         60
# 3       1.0  -67.562239  0.0    0   0.231446     0.0         60
# 4       1.0  -63.553410  0.0    0  -0.990216     0.0         60

# %%
# Generate data for STDP
data1 = data[data['ptl_idx']==1]
data1_gen, targets1 = data_aug_knn.STDP_dw_gen(n_neighbors=3)

# %%
# Obtain the gp mean
params = {'amp_kernel': 1,
 'length_scale': 0.1,
 'power_sc': 0.2,
 'sigma_noise': 1.0}

x_stdp, _, x_stdp_test, y_stdp_test, y_stdp = data_aug_gp.stdp_gp(**params)

x_stdp_train, x_stdp_vali, y_stdp_train, y_stdp_vali = train_test_split(x_stdp, y_stdp, test_size=0.2)

# %%
plt.plot(x_stdp_train, y_stdp_train, 'o',label='train_data')
plt.plot(x_stdp_vali, y_stdp_vali, 'o',label='vali_data')
plt.plot(x_stdp_test,y_stdp_test, 'o', label='test_data')
plt.legend(loc='upper left')
plt.axis([-110,110,-50,110])

# %%
# Pute time information into dataframe
data_stdp_train = data_aug_gp.STDP_dw_gen(x_stdp_train)
data_stdp_vali = data_aug_gp.STDP_dw_gen(x_stdp_vali)
data_stdp_test = data_aug_gp.STDP_dw_gen(x_stdp_test.reshape(-1,1))

# %%
data_stdp_train.sort(columns='dt1')
# Out:
#      ptl_idx  pre_spk_num  pre_spk_freq  post_spk_num  post_spk_freq  ptl_occ  \
# 17       1.0          1.0           0.0           1.0            0.0     60.0
# 114      1.0          1.0           0.0           1.0            0.0     60.0
# 50       1.0          1.0           0.0           1.0            0.0     60.0
# 22       1.0          1.0           0.0           1.0            0.0     60.0
# 11       1.0          1.0           0.0           1.0            0.0     60.0
# 125      1.0          1.0           0.0           1.0            0.0     60.0
# 63       1.0          1.0           0.0           1.0            0.0     60.0
# 28       1.0          1.0           0.0           1.0            0.0     60.0
# 136      1.0          1.0           0.0           1.0            0.0     60.0
# 34       1.0          1.0           0.0           1.0            0.0     60.0
# 75       1.0          1.0           0.0           1.0            0.0     60.0
# 81       1.0          1.0           0.0           1.0            0.0     60.0
# 83       1.0          1.0           0.0           1.0            0.0     60.0
# 111       1.0   74.517156  0.0  0.0 -1.32259     0.0       60.0
# 139       1.0   75.513870  0.0  0.0 -1.32259     0.0       60.0
# 133       1.0   76.510585  0.0  0.0 -1.32259     0.0       60.0
# 7         1.0   77.507300  0.0  0.0 -1.32259     0.0       60.0
# 46        1.0   78.504014  0.0  0.0 -1.32259     0.0       60.0
# 30        1.0   79.500729  0.0  0.0 -1.32259     0.0       60.0
# 59        1.0   80.497443  0.0  0.0 -1.32259     0.0       60.0
# 106       1.0   83.487587  0.0  0.0 -1.32259     0.0       60.0
# 67        1.0   85.481016  0.0  0.0 -1.32259     0.0       60.0
# 3         1.0   86.477731  0.0  0.0 -1.32259     0.0       60.0
# 150       1.0   88.471160  0.0  0.0 -1.32259     0.0       60.0
# 60        1.0   91.461304  0.0  0.0 -1.32259     0.0       60.0
# 96        1.0   92.458019  0.0  0.0 -1.32259     0.0       60.0
# 6         1.0   93.454733  0.0  0.0 -1.32259     0.0       60.0
# 140       1.0   94.451448  0.0  0.0 -1.32259     0.0       60.0
# 40        1.0   95.448163  0.0  0.0 -1.32259     0.0       60.0
#
# [160 rows x 13 columns]

# %%
data_stdp_train.shape, y_stdp_train.shape, data_stdp_vali.shape, y_stdp_vali.shape,data_stdp_test.shape, y_stdp_test.shape
# Out:
# ((160, 13), (160, 1), (40, 13), (40, 1), (9, 13), (9, 1))

# %%
# Obtain augmented data from quadruplet protocol
params = {'amp_kernel': 1,
 'length_scale': 0.45,
 'power_sc': 0.4,
 'sigma_noise': 1.2}

x_quad, _, x_quad_test, y_quad_test, y_quad = data_aug_gp.quad_gp(**params)

# Split into training and validation set
x_quad_train, x_quad_vali, y_quad_train, y_quad_vali = train_test_split(x_quad, y_quad, test_size=0.2)

plt.plot(x_quad_train, y_quad_train, 'o', label='train_data')
plt.plot(x_quad_vali, y_quad_vali, 'o', label='vali_data')
plt.plot(x_quad_test, y_quad_test, 'o', label='test_data')
plt.legend(loc='upper left')

# %%
# Put dt information into dataframe
data_quad_train = data_aug_gp.quad_dw_gen(x_quad_train)
data_quad_vali = data_aug_gp.quad_dw_gen(x_quad_vali)
data_quad_test = data_aug_gp.quad_dw_gen(x_quad_test.reshape(-1,1))

# %%
data_quad_train.shape, y_quad_train.shape, data_quad_vali.shape, y_quad_vali.shape, data_quad_test.shape, y_quad_test.shape
# Out:
# ((160, 13), (160, 1), (40, 13), (40, 1), (12, 13), (12, 1))

# %%
# Generate data for Triplet
dt = np.array([-10, -5, 0, 5, 10]).reshape(-1,1)
data_trip, y_trip, data_trip_test, y_trip_test = data_aug_gp.triplet_dw_gen(n_samples=1)

# Split the triplet data into training and validation
np.random.seed(10)
idx = np.random.permutation(len(data_trip))
data_trip_train = data_trip.iloc[idx[:int(len(data_trip)*0.8)]]
y_trip_train = y_trip[idx[:int(len(data_trip)*0.8)]]
data_trip_vali = data_trip.iloc[idx[int(len(data_trip)*0.8):]]
y_trip_vali = y_trip[idx[int(len(data_trip)*0.8):]]

# %%
data_trip_train.shape, data_trip_vali.shape, data_trip_test.shape
# Out:
# ((6, 13), (2, 13), (10, 13))

# %%
# Combine data from stdp and quadruplet
data_gen_train = pd.concat([data_stdp_train, data_trip_train, data_quad_train], axis=0)
y_train = np.concatenate([y_stdp_train, y_trip_train, y_quad_train])
data_gen_vali = pd.concat([data_stdp_vali, data_trip_vali, data_quad_vali], axis=0)
y_vali = np.concatenate([y_stdp_vali, y_trip_vali, y_quad_vali])
data_gen_test = pd.concat([data_stdp_test, data_trip_test, data_quad_test], axis=0)
y_test = np.concatenate([y_stdp_test, y_trip_test, y_quad_test])

# %%
data_gen_train.shape, y_train.shape, data_gen_vali.shape, y_vali.shape
# Out:
# ((326, 13), (326, 1), (82, 13), (82, 1))

# %%
trip_para = pd.read_pickle('/src/Plasticity_Ker/data/Gerstner_trip_para_df')
trip_para
# Reorder columns to match parameter of the model
trip_para = trip_para[['A2_+', 'A3_-', 'A2_-', 'A3_+', 'Tau_+', 'Tau_x', 'Tau_-', 'Tau_y']]

# Visualize kernel
from modelval.kernel import KernelGen
ker_test = KernelGen()

para = trip_para.loc[('Hippo_AlltoAll', 'Full'), :]
a = para[:4].values
tau = para[4:].values
reso_set = 2
tau_pre_post = tau[0]/reso_set  # ms
tau_post_pre = tau[2]/reso_set # ms

len_kernel = 101
len_trip = 151
ker_test = KernelGen(len_kernel=len_kernel, len_trip=len_trip)
ker_test.trip_model_ker(para, data_name='Hippocampus')

# %%
ker_test.kernel_post_post.shape
# Out:
# (151, 1)

# %%
ker_test.kernel_scale.shape
# Out:
# (3,)

# %%
# Generat the spike trains and targets for STDP
data_hippo = data[data['ptl_idx']<5]
ptl_list = [1,2,3,4]
spk_len = int(data_hippo['train_len'].max() * 1000 / ker_test.reso_kernel)
if_noise = 1
aug_times = [1,1,1,1]
spk_pairs_train, targets_train = arb_w_gen(df=data_gen_train, ptl_list=ptl_list, targets=y_train, if_noise=if_noise, spk_len=spk_len, kernel=ker_test, net_type='triplet', aug_times=aug_times)
spk_pairs_vali, targets_vali = arb_w_gen(df=data_gen_vali, ptl_list=ptl_list, targets=y_vali, if_noise=if_noise, spk_len=spk_len, kernel=ker_test, net_type='triplet', aug_times=aug_times)

# %%
data_gen_train
# Out:
#      ptl_idx  pre_spk_num  pre_spk_freq  post_spk_num  post_spk_freq  ptl_occ  \
# 0        1.0          1.0           0.0           1.0            0.0     60.0
# 1        1.0          1.0           0.0           1.0            0.0     60.0
# 2        1.0          1.0           0.0           1.0            0.0     60.0
# 3        1.0          1.0           0.0           1.0            0.0     60.0
# 4        1.0          1.0           0.0           1.0            0.0     60.0
# 5        1.0          1.0           0.0           1.0            0.0     60.0
# 6        1.0          1.0           0.0           1.0            0.0     60.0
# 7        1.0          1.0           0.0           1.0            0.0     60.0
# 8        1.0          1.0           0.0           1.0            0.0     60.0
# 9        1.0          1.0           0.0           1.0            0.0     60.0
# 10       1.0          1.0           0.0           1.0            0.0     60.0
# 142       1.0    5.000000   49.807075 -5.0  8.242655     0.0       60.0
# 143       1.0    5.000000   85.250001 -5.0  8.242655     0.0       60.0
# 144       1.0    5.000000  -87.303178 -5.0  8.242655     0.0       60.0
# 145       1.0    5.000000  -53.749091 -5.0  8.242655     0.0       60.0
# 146       1.0    5.000000  -26.486395 -5.0  8.242655     0.0       60.0
# 147       1.0    5.000000   42.510002 -5.0  8.242655     0.0       60.0
# 148       1.0    5.000000  -48.506265 -5.0  8.242655     0.0       60.0
# 149       1.0    5.000000   17.491466 -5.0  8.242655     0.0       60.0
# 150       1.0    5.000000  105.056342 -5.0  8.242655     0.0       60.0
# 151       1.0    5.000000  -85.206048 -5.0  8.242655     0.0       60.0
# 152       1.0    5.000000   87.334879 -5.0  8.242655     0.0       60.0
# 153       1.0    5.000000   59.189026 -5.0  8.242655     0.0       60.0
# 154       1.0    5.000000  -82.060352 -5.0  8.242655     0.0       60.0
# 155       1.0    5.000000   35.212929 -5.0  8.242655     0.0       60.0
# 156       1.0    5.000000   18.533905 -5.0  8.242655     0.0       60.0
# 157       1.0    5.000000  -19.146438 -5.0  8.242655     0.0       60.0
# 158       1.0    5.000000   73.783172 -5.0  8.242655     0.0       60.0
# 159       1.0    5.000000   74.825611 -5.0  8.242655     0.0       60.0
#
# [326 rows x 13 columns]

# %%
# Create the network
ground_truth_init = 0
reg_scale=(10,50,100,200)
init_seed=(4,5,6,7,8)

toy_data_net = network.TripNet(kernel=ker_test, ground_truth_init=ground_truth_init, reg_scale=reg_scale, n_input=spk_pairs_train.shape[1])

# %%
# Create the trainer
save_dir= '/src/Plasticity_Ker/model/Trip_ptl1_4_real_aug_gp_mean_noise_alpha1_alpha3_10_long_post_post_diff_bias'
toy_net_trainer = trainer.Trainer(toy_data_net.mse, toy_data_net.loss, input_name=toy_data_net.inputs, target_name=toy_data_net.target, save_dir=save_dir, optimizer_config={'learning_rate': toy_data_net.lr})

# %%
train_data = dataset.Dataset(spk_pairs_train, targets_train)
vali_data = dataset.Dataset(spk_pairs_vali, targets_vali)

# %%
w_pre = toy_net_trainer.evaluate(ops=toy_data_net.kernel_pre)
w_post = toy_net_trainer.evaluate(ops=toy_data_net.kernel_post)
w_post_post = toy_net_trainer.evaluate(ops=toy_data_net.kernel_post_post)
scaler = toy_net_trainer.evaluate(ops=toy_data_net.scaler)
fc_w = toy_net_trainer.evaluate(ops=toy_data_net.fc_w)
bias = toy_net_trainer.evaluate(ops=toy_data_net.bias)
plt.plot(w_pre,  label='ker_pre_init')
plt.plot(w_post,  label='ker_post_init')
plt.plot(w_post_post,  label='ker_post_post_init')

plt.legend()
print(fc_w, bias, scaler)
# Out:
# [-0.22614121 -0.27994752  0.95375919] [[ 0.]
#  [ 0.]
#  [ 0.]
#  [ 0.]] [[ 1.00032043]
#  [-0.51089203]
#  [ 1.09062028]
#  [ 0.75781369]]

# %%
# Learn the kernel from random initialization
learning_rate = 0.001
iterations = 5
min_error = -1
for i in range(iterations):
    toy_net_trainer.train(train_data, vali_data, batch_size=128, min_error=min_error, feed_dict={toy_data_net.lr: learning_rate})
    learning_rate = learning_rate/3
# Out:
# Initial validation mse=116.70379
# Global Step 0150 and Step 0150: validation mse=101.84241
# Updated min validation loss!Saving model...
# Global Step 0200 and Step 0200: validation mse=100.85700
# Updated min validation loss!Saving model...
# Global Step 0250 and Step 0250: validation mse=99.51279
# Updated min validation loss!Saving model...
# Global Step 0300 and Step 0300: validation mse=96.69669
# Updated min validation loss!Saving model...
# Global Step 0350 and Step 0350: validation mse=91.53746
# Updated min validation loss!Saving model...
# Global Step 0400 and Step 0400: validation mse=83.68510
# Updated min validation loss!Saving model...
# Global Step 0450 and Step 0450: validation mse=74.29578
# Updated min validation loss!Saving model...
# Global Step 0500 and Step 0500: validation mse=64.57708
# Updated min validation loss!Saving model...
# Global Step 0550 and Step 0550: validation mse=55.85965
# Updated min validation loss!Saving model...
# Global Step 0600 and Step 0600: validation mse=49.34548
# Updated min validation loss!Saving model...
# Global Step 0650 and Step 0650: validation mse=45.02169
# Updated min validation loss!Saving model...
# Global Step 0700 and Step 0700: validation mse=42.21578
# Updated min validation loss!Saving model...
# Global Step 0750 and Step 0750: validation mse=40.25594
# Updated min validation loss!Saving model...
# Global Step 0800 and Step 0800: validation mse=38.65226
# Updated min validation loss!Saving model...
# Global Step 0850 and Step 0850: validation mse=37.21106
# Updated min validation loss!Saving model...
# Global Step 0900 and Step 0900: validation mse=35.84322
# Updated min validation loss!Saving model...
# Global Step 0950 and Step 0950: validation mse=34.61721
# Updated min validation loss!Saving model...
# Global Step 1000 and Step 1000: validation mse=33.37781
# Updated min validation loss!Saving model...
# Global Step 1050 and Step 1050: validation mse=32.15841
# Updated min validation loss!Saving model...
# Global Step 1100 and Step 1100: validation mse=30.95803
# Updated min validation loss!Saving model...
# Global Step 1150 and Step 1150: validation mse=29.81808
# Updated min validation loss!Saving model...
# Global Step 1200 and Step 1200: validation mse=28.71456
# Updated min validation loss!Saving model...
# Global Step 1250 and Step 1250: validation mse=27.59657
# Updated min validation loss!Saving model...
# Global Step 1300 and Step 1300: validation mse=26.54221
# Updated min validation loss!Saving model...
# Global Step 1350 and Step 1350: validation mse=25.49448
# Updated min validation loss!Saving model...
# Global Step 1400 and Step 1400: validation mse=24.52818
# Updated min validation loss!Saving model...
# Global Step 1450 and Step 1450: validation mse=23.62330
# Updated min validation loss!Saving model...
# Global Step 1500 and Step 1500: validation mse=22.83087
# Updated min validation loss!Saving model...
# Global Step 1550 and Step 1550: validation mse=22.09288
# Updated min validation loss!Saving model...
# Global Step 1600 and Step 1600: validation mse=21.42212
# Updated min validation loss!Saving model...
# Global Step 1650 and Step 1650: validation mse=20.85465
# Updated min validation loss!Saving model...
# Global Step 1700 and Step 1700: validation mse=20.40059
# Updated min validation loss!Saving model...
# Global Step 1750 and Step 1750: validation mse=19.85828
# Updated min validation loss!Saving model...
# Global Step 1800 and Step 1800: validation mse=19.50384
# Updated min validation loss!Saving model...
# Global Step 1850 and Step 1850: validation mse=19.18117
# Updated min validation loss!Saving model...
# Global Step 1900 and Step 1900: validation mse=18.85031
# Updated min validation loss!Saving model...
# Global Step 1950 and Step 1950: validation mse=18.61595
# Updated min validation loss!Saving model...
# Global Step 2000 and Step 2000: validation mse=18.25178
# Updated min validation loss!Saving model...
# Global Step 2050 and Step 2050: validation mse=18.13621
# Updated min validation loss!Saving model...
# Global Step 2100 and Step 2100: validation mse=17.92516
# Updated min validation loss!Saving model...
# Global Step 2150 and Step 2150: validation mse=17.78168
# Updated min validation loss!Saving model...
# Global Step 2200 and Step 2200: validation mse=17.65581
# Updated min validation loss!Saving model...
# Global Step 2250 and Step 2250: validation mse=17.38175
# Updated min validation loss!Saving model...
# Global Step 2300 and Step 2300: validation mse=17.21998
# Updated min validation loss!Saving model...
# Global Step 2350 and Step 2350: validation mse=17.10583
# Updated min validation loss!Saving model...
# Global Step 2400 and Step 2400: validation mse=16.91024
# Updated min validation loss!Saving model...
# Global Step 2450 and Step 2450: validation mse=16.73428
# Updated min validation loss!Saving model...
# Global Step 2500 and Step 2500: validation mse=16.56938
# Updated min validation loss!Saving model...
# Global Step 2550 and Step 2550: validation mse=16.43769
# Updated min validation loss!Saving model...
# Global Step 2600 and Step 2600: validation mse=16.32326
# Updated min validation loss!Saving model...
# Global Step 2650 and Step 2650: validation mse=16.16221
# Updated min validation loss!Saving model...
# Global Step 2700 and Step 2700: validation mse=16.08432
# Updated min validation loss!Saving model...
# Global Step 2750 and Step 2750: validation mse=15.96813
# Updated min validation loss!Saving model...
# Global Step 2800 and Step 2800: validation mse=15.82197
# Updated min validation loss!Saving model...
# Global Step 2850 and Step 2850: validation mse=15.72068
# Updated min validation loss!Saving model...
# Global Step 2900 and Step 2900: validation mse=15.59223
# Updated min validation loss!Saving model...
# Global Step 2950 and Step 2950: validation mse=15.50678
# Updated min validation loss!Saving model...
# Global Step 3000 and Step 3000: validation mse=15.34943
# Updated min validation loss!Saving model...
# Global Step 3050 and Step 3050: validation mse=15.16156
# Updated min validation loss!Saving model...
# Global Step 3100 and Step 3100: validation mse=15.05480
# Updated min validation loss!Saving model...
# Global Step 3150 and Step 3150: validation mse=14.94059
# Updated min validation loss!Saving model...
# Global Step 3200 and Step 3200: validation mse=14.97374
# Global Step 3250 and Step 3250: validation mse=14.82337
# Updated min validation loss!Saving model...
# Global Step 3300 and Step 3300: validation mse=14.74086
# Updated min validation loss!Saving model...
# Global Step 3350 and Step 3350: validation mse=14.48909
# Updated min validation loss!Saving model...
# Global Step 3400 and Step 3400: validation mse=14.47300
# Updated min validation loss!Saving model...
# Global Step 3450 and Step 3450: validation mse=14.32844
# Updated min validation loss!Saving model...
# Global Step 3500 and Step 3500: validation mse=14.18583
# Updated min validation loss!Saving model...
# Global Step 3550 and Step 3550: validation mse=14.09110
# Updated min validation loss!Saving model...
# Global Step 3600 and Step 3600: validation mse=13.99661
# Updated min validation loss!Saving model...
# Global Step 3650 and Step 3650: validation mse=13.86189
# Updated min validation loss!Saving model...
# Global Step 3700 and Step 3700: validation mse=13.74583
# Updated min validation loss!Saving model...
# Global Step 3750 and Step 3750: validation mse=13.67321
# Updated min validation loss!Saving model...
# Global Step 3800 and Step 3800: validation mse=13.55490
# Updated min validation loss!Saving model...
# Global Step 3850 and Step 3850: validation mse=13.48545
# Updated min validation loss!Saving model...
# Global Step 3900 and Step 3900: validation mse=13.38039
# Updated min validation loss!Saving model...
# Global Step 3950 and Step 3950: validation mse=13.20331
# Updated min validation loss!Saving model...
# Global Step 4000 and Step 4000: validation mse=13.11303
# Updated min validation loss!Saving model...
# Global Step 4050 and Step 4050: validation mse=13.05317
# Updated min validation loss!Saving model...
# Global Step 4100 and Step 4100: validation mse=12.90817
# Updated min validation loss!Saving model...
# Global Step 4150 and Step 4150: validation mse=12.81710
# Updated min validation loss!Saving model...
# Global Step 4200 and Step 4200: validation mse=12.70913
# Updated min validation loss!Saving model...
# Global Step 4250 and Step 4250: validation mse=12.62922
# Updated min validation loss!Saving model...
# Global Step 4300 and Step 4300: validation mse=12.53546
# Updated min validation loss!Saving model...
# Global Step 4350 and Step 4350: validation mse=12.41430
# Updated min validation loss!Saving model...
# Global Step 4400 and Step 4400: validation mse=12.29520
# Updated min validation loss!Saving model...
# Global Step 4450 and Step 4450: validation mse=12.18504
# Updated min validation loss!Saving model...
# Global Step 4500 and Step 4500: validation mse=12.14686
# Updated min validation loss!Saving model...
# Global Step 4550 and Step 4550: validation mse=11.98659
# Updated min validation loss!Saving model...
# Global Step 4600 and Step 4600: validation mse=11.91410
# Updated min validation loss!Saving model...
# Global Step 4650 and Step 4650: validation mse=11.78644
# Updated min validation loss!Saving model...
# Global Step 4700 and Step 4700: validation mse=11.70615
# Updated min validation loss!Saving model...
# Global Step 4750 and Step 4750: validation mse=11.60516
# Updated min validation loss!Saving model...
# Global Step 4800 and Step 4800: validation mse=11.52969
# Updated min validation loss!Saving model...
# Global Step 4850 and Step 4850: validation mse=11.48182
# Updated min validation loss!Saving model...
# Global Step 4900 and Step 4900: validation mse=11.35000
# Updated min validation loss!Saving model...
# Global Step 4950 and Step 4950: validation mse=11.27632
# Updated min validation loss!Saving model...
# Global Step 5000 and Step 5000: validation mse=11.24832
# Updated min validation loss!Saving model...
# Global Step 5050 and Step 5050: validation mse=11.11510
# Updated min validation loss!Saving model...
# Global Step 5100 and Step 5100: validation mse=11.09111
# Updated min validation loss!Saving model...
# Global Step 5150 and Step 5150: validation mse=11.04344
# Updated min validation loss!Saving model...
# Global Step 5200 and Step 5200: validation mse=10.98356
# Updated min validation loss!Saving model...
# Global Step 5250 and Step 5250: validation mse=10.90152
# Updated min validation loss!Saving model...
# Global Step 5300 and Step 5300: validation mse=10.96190
# Global Step 5350 and Step 5350: validation mse=10.86162
# Updated min validation loss!Saving model...
# Global Step 5400 and Step 5400: validation mse=10.87973
# Global Step 5450 and Step 5450: validation mse=10.80420
# Updated min validation loss!Saving model...
# Global Step 5500 and Step 5500: validation mse=10.86850
# Global Step 5550 and Step 5550: validation mse=10.85793
# Global Step 5600 and Step 5600: validation mse=10.90744
# Global Step 5650 and Step 5650: validation mse=10.96200
# Global Step 5700 and Step 5700: validation mse=10.94795
# Global Step 5750 and Step 5750: validation mse=11.01204
# Global Step 5800 and Step 5800: validation mse=11.05842
# Global Step 5850 and Step 5850: validation mse=11.09289
# Global Step 5900 and Step 5900: validation mse=11.14149
# Global Step 5950 and Step 5950: validation mse=11.18338
# Global Step 6000 and Step 6000: validation mse=11.17804
# Global Step 6050 and Step 6050: validation mse=11.11814
# Global Step 6100 and Step 6100: validation mse=11.18750
# Global Step 6150 and Step 6150: validation mse=11.17713
# Global Step 6200 and Step 6200: validation mse=11.17811
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 6250 and Step 0050: validation mse=10.85365
# Global Step 6300 and Step 0100: validation mse=10.87715
# Global Step 6350 and Step 0150: validation mse=10.88130
# Global Step 6400 and Step 0200: validation mse=10.89163
# Global Step 6450 and Step 0250: validation mse=10.88476
# Global Step 6500 and Step 0300: validation mse=10.89458
# Global Step 6550 and Step 0350: validation mse=10.89421
# Global Step 6600 and Step 0400: validation mse=10.90522
# Global Step 6650 and Step 0450: validation mse=10.95164
# Global Step 6700 and Step 0500: validation mse=10.95026
# Global Step 6750 and Step 0550: validation mse=10.94966
# Global Step 6800 and Step 0600: validation mse=10.96361
# Global Step 6850 and Step 0650: validation mse=10.98744
# Global Step 6900 and Step 0700: validation mse=11.01537
# Global Step 6950 and Step 0750: validation mse=10.99667
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 7000 and Step 0050: validation mse=10.83496
# Global Step 7050 and Step 0100: validation mse=10.85644
# Global Step 7100 and Step 0150: validation mse=10.85986
# Global Step 7150 and Step 0200: validation mse=10.87567
# Global Step 7200 and Step 0250: validation mse=10.88290
# Global Step 7250 and Step 0300: validation mse=10.88179
# Global Step 7300 and Step 0350: validation mse=10.88330
# Global Step 7350 and Step 0400: validation mse=10.88353
# Global Step 7400 and Step 0450: validation mse=10.89334
# Global Step 7450 and Step 0500: validation mse=10.89038
# Global Step 7500 and Step 0550: validation mse=10.89831
# Global Step 7550 and Step 0600: validation mse=10.90340
# Global Step 7600 and Step 0650: validation mse=10.89965
# Global Step 7650 and Step 0700: validation mse=10.90255
# Global Step 7700 and Step 0750: validation mse=10.90917
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 7750 and Step 0050: validation mse=10.82030
# Global Step 7800 and Step 0100: validation mse=10.83534
# Global Step 7850 and Step 0150: validation mse=10.84935
# Global Step 7900 and Step 0200: validation mse=10.84644
# Global Step 7950 and Step 0250: validation mse=10.84721
# Global Step 8000 and Step 0300: validation mse=10.84998
# Global Step 8050 and Step 0350: validation mse=10.85068
# Global Step 8100 and Step 0400: validation mse=10.85809
# Global Step 8150 and Step 0450: validation mse=10.86589
# Global Step 8200 and Step 0500: validation mse=10.86643
# Global Step 8250 and Step 0550: validation mse=10.86423
# Global Step 8300 and Step 0600: validation mse=10.86341
# Global Step 8350 and Step 0650: validation mse=10.86613
# Global Step 8400 and Step 0700: validation mse=10.87420
# Global Step 8450 and Step 0750: validation mse=10.87397
# Early Stopping!!!
# Restoring the best parameters...
# Global Step 8500 and Step 0050: validation mse=10.81043
# Global Step 8550 and Step 0100: validation mse=10.81374
# Global Step 8600 and Step 0150: validation mse=10.82025
# Global Step 8650 and Step 0200: validation mse=10.82556
# Global Step 8700 and Step 0250: validation mse=10.82830
# Global Step 8750 and Step 0300: validation mse=10.83417
# Global Step 8800 and Step 0350: validation mse=10.83524
# Global Step 8850 and Step 0400: validation mse=10.83838
# Global Step 8900 and Step 0450: validation mse=10.84012
# Global Step 8950 and Step 0500: validation mse=10.84081
# Global Step 9000 and Step 0550: validation mse=10.84209
# Global Step 9050 and Step 0600: validation mse=10.84405
# Global Step 9100 and Step 0650: validation mse=10.84521
# Global Step 9150 and Step 0700: validation mse=10.84689
# Global Step 9200 and Step 0750: validation mse=10.84972
# Early Stopping!!!
# Restoring the best parameters...

# %%
toy_net_trainer.restore_best()
w_pre = toy_net_trainer.evaluate(ops=toy_data_net.kernel_pre)
w_post = toy_net_trainer.evaluate(ops=toy_data_net.kernel_post)
w_post_post = toy_net_trainer.evaluate(ops=toy_data_net.kernel_post_post)
fc_w = toy_net_trainer.evaluate(ops=toy_data_net.fc_w)
bias = toy_net_trainer.evaluate(ops=toy_data_net.bias)
scaler = toy_net_trainer.evaluate(ops=toy_data_net.scaler)

plt.plot(-1*w_pre, label='ker_pre_trained')

plt.plot(-1*w_post, label='ker_post_trained')
plt.plot(-1*w_post_post, label='ker_post_post_trained')
plt.legend()
print([fc_w, bias, scaler])
# Out:
# [array([-0.96368682, -0.53607607, -2.59652686], dtype=float32), array([[-0.1829679 ],
#        [ 0.53013915],
#        [-2.85659361],
#        [ 1.03106916]], dtype=float32), array([[ 2.22944617],
#        [ 1.86227965],
#        [ 1.40850878],
#        [ 2.54353023]], dtype=float32)]

# %%
# Test effect of smoothed kernel
w_pre_sm = w_pre
w_post_sm = w_post 
w_post_post_sm = w_post_post
w_pre_sm[:51] = data_aug_gp.smooth(w_pre[:51], width=10)
w_post_sm[:49] = data_aug_gp.smooth(w_post[:49], width=10)
w_post_post_sm[:100] = data_aug_gp.smooth(w_post_post[:100], width=5)

plt.plot(-1 * w_pre_sm)
plt.plot(-1 * w_post_sm)
plt.plot(-1*w_post_post_sm)

ker_test.kernel_pre = w_pre_sm
ker_test.kernel_post = w_post_sm
ker_test.kernel_post_post= w_post_post_sm
ker_test.kernel_scale = fc_w
ker_test.bias = bias
ker_test.scale = scaler

# %% [markdown]
# Compare the target and prediction

# %%
# Updated the kernel as trained kernel
ker_test.kernel_pre = w_pre
ker_test.kernel_post = w_post
ker_test.kernel_post_post= w_post_post
ker_test.kernel_scale = fc_w
ker_test.bias = bias
ker_test.scale = scaler

# %%
# # Generate training predictions
# spk_len = int(data['train_len'].max() * 1000 / ker_test.reso_kernel)
# _, predictions_train = arb_w_gen(spk_pairs=spk_pairs_train, spk_len=spk_len, kernel=ker_test, net_type='triplet')

# ptl_len = np.array([160,3,160,3])
# rep_time = np.array([1,1,1,1])
# ptl_len, targets_out, predictions_out = data_aug_knn.target_pred_gen(targets_train, predictions_train, ptl_len, rep_time)

# # Calculate the total sum of squares
# R2 = 1 - np.sum(np.square(predictions_train-targets_train))/(np.square(np.std(targets_train))*(len(targets_train)-1))

# plt.plot(np.linspace(-30,50,80), np.linspace(-30,50,80),'k--')
# ptl_type = ['stdp', 'trip1', 'quad','trip2']
# for i in range(len(ptl_len)):
#     plt.plot(targets_out[i], predictions_out[i],'o', label=ptl_type[i])

# plt.title('Training data (R2=%0.2f)'%(R2))
# plt.legend()

# %%
# Generate validation predictions
spk_len = int(data['train_len'].max() * 1000 / ker_test.reso_kernel)
_, predictions_vali = arb_w_gen(spk_pairs=spk_pairs_vali, spk_len=spk_len, kernel=ker_test, net_type='triplet')

ptl_len = np.array([40,1,40,1])
rep_time = np.array([1,1,1,1])
ptl_len, targets_out, predictions_out = data_aug_knn.target_pred_gen(targets_vali, predictions_vali, ptl_len, rep_time)

# Calculate the total sum of squares
R2 = 1 - np.sum(np.square(predictions_vali-targets_vali))/(np.square(np.std(targets_vali))*(len(targets_vali)-1))
corr = np.sqrt(R2)

plt.plot(np.linspace(-30,50,80), np.linspace(-30,50,80),'k--')
ptl_type = ['stdp', 'trip1', 'quad','trip2']
for i in range(len(ptl_len)):
    plt.plot(targets_out[i], predictions_out[i],'o', label=ptl_type[i])

plt.title('Validation data (R2=%0.2f)'%(R2))
plt.legend()

# %%
# Generat the spike trains and targets for STDP
data3 = data[data['ptl_idx']==3]
ptl_list = [1,2,3,4]
spk_len = int(data3['train_len'].max() * 1000 / ker_test.reso_kernel)
if_noise = 0
aug_times = [1,1,1,1]
spk_pairs_test, targets_test = arb_w_gen(df=data_gen_test, ptl_list=ptl_list, targets=y_test, if_noise=if_noise, spk_len=spk_len, kernel=ker_test, net_type='triplet', aug_times=aug_times)

# %%
# Generate test predictions
spk_len = int(data['train_len'].max() * 1000 / ker_test.reso_kernel)
_, predictions_test = arb_w_gen(spk_pairs=spk_pairs_test, spk_len=spk_len, kernel=ker_test, net_type='triplet')

ptl_len = np.array([12,7,12,4])
rep_time = np.array([1,1,1,1])
ptl_len, targets_out, predictions_out = data_aug_knn.target_pred_gen(targets_test, predictions_test, ptl_len, rep_time)

# Calculate the total sum of squares
R2 = 1 - np.sum(np.square(predictions_test-targets_test))/(np.square(np.std(targets_test))*(len(targets_test)-1))
corr = np.sqrt(R2)

plt.plot(np.linspace(-30,50,80), np.linspace(-30,50,80),'k--')
ptl_type = ['stdp', 'trip1', 'quad','trip2']
for i in range(len(ptl_len)):
    plt.plot(targets_out[i], predictions_out[i],'o', label=ptl_type[i])

plt.title('Testing data (R2=%0.2f)'%(R2))
plt.legend()
